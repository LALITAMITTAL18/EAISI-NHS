# %% [markdown]
# # Knee Replacement Provider Data Merging
#
# This notebook loads and merges the Knee Replacement Provider data from 2016/17, 2017/18, and 2018/19.

# %%
import pandas as pd
import os

# %%
# Define file paths
files = {
    "1617": "../external/Knee Replacement Provider 1617.csv",
    "1718": "../external/Knee Replacements Provider 1718.csv",
    "1819": "../external/Knee Replacement Provider 1819.csv"
}

# Load dataframes with appropriate separators
df_1617 = pd.read_csv(files["1617"], sep=',')
df_1718 = pd.read_csv(files["1718"], sep=',')
df_1819 = pd.read_csv(files["1819"], sep=',')
# Out:
# C:\Users\mittall\AppData\Local\Temp\ipykernel_19652\2607060915.py:9: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1617 = pd.read_csv(files["1617"], sep=',')
# C:\Users\mittall\AppData\Local\Temp\ipykernel_19652\2607060915.py:10: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1718 = pd.read_csv(files["1718"], sep=',')
# C:\Users\mittall\AppData\Local\Temp\ipykernel_19652\2607060915.py:11: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_1819 = pd.read_csv(files["1819"], sep=',')

# %%
# Check columns
print("Columns in 1617:")
print(df_1617.columns.tolist())
print("\nColumns in 1718:")
print(df_1718.columns.tolist())
print("\nColumns in 1819:")
print(df_1819.columns.tolist())

# Check if columns are the same
cols_1617 = set(df_1617.columns)
cols_1718 = set(df_1718.columns)
cols_1819 = set(df_1819.columns)

if cols_1617 == cols_1718 == cols_1819:
    print("\nAll columns are the same.")
else:
    print("\nColumns differ:")
    print("Unique to 1617:", cols_1617 - cols_1718 - cols_1819)
    print("Unique to 1718:", cols_1718 - cols_1617 - cols_1819)
    print("Unique to 1819:", cols_1819 - cols_1617 - cols_1718)

# Check shapes
print("\nShape of 1617:", df_1617.shape)
print("Shape of 1718:", df_1718.shape)
print("Shape of 1819:", df_1819.shape)
# Out:
# Columns in 1617:
# ['Provider Code', 'Procedure', 'Revision Flag', 'Year', 'Age Band', 'Gender', 'Pre-Op Q Assisted', 'Pre-Op Q Assisted By', 'Pre-Op Q Symptom Period', 'Pre-Op Q Previous Surgery', 'Pre-Op Q Living Arrangements', 'Pre-Op Q Disability', 'Heart Disease', 'High Bp', 'Stroke', 'Circulation', 'Lung Disease', 'Diabetes', 'Kidney Disease', 'Nervous System', 'Liver Disease', 'Cancer', 'Depression', 'Arthritis', 'Pre-Op Q Mobility', 'Pre-Op Q Self-Care', 'Pre-Op Q Activity', 'Pre-Op Q Discomfort', 'Pre-Op Q Anxiety', 'Pre-Op Q EQ5D Index Profile', 'Pre-Op Q EQ5D Index', 'Post-Op Q Assisted', 'Post-Op Q Assisted By', 'Post-Op Q Living Arrangements', 'Post-Op Q Disability', 'Post-Op Q Mobility', 'Post-Op Q Self-Care', 'Post-Op Q Activity', 'Post-Op Q Discomfort', 'Post-Op Q Anxiety', 'Post-Op Q Satisfaction', 'Post-Op Q Sucess', 'Post-Op Q Allergy', 'Post-Op Q Bleeding', 'Post-Op Q Wound', 'Post-Op Q Urine', 'Post-Op Q Further Surgery', 'Post-Op Q Readmitted', 'Post-Op Q EQ5D Index Profile', 'Post-Op Q EQ5D Index', 'Knee Replacement EQ 5D Index Post-Op Q Predicted', 'Pre-Op Q EQ VAS', 'Post-Op Q EQ VAS', 'Knee Replacement EQ VAS_Post-Op Q Predicted', 'Knee Replacement Pre-Op Q Pain', 'Knee Replacement Pre-Op Q Night Pain', 'Knee Replacement Pre-Op Q Washing', 'Knee Replacement Pre-Op Q Transport', 'Knee Replacement Pre-Op Q Walking', 'Knee Replacement Pre-Op Q Standing', 'Knee Replacement Pre-Op Q Limping', 'Knee Replacement Pre-Op Q Kneeling', 'Knee Replacement Pre-Op Q Work', 'Knee Replacement Pre-Op Q Confidence', 'Knee Replacement Pre-Op Q Shopping', 'Knee Replacement Pre-Op Q Stairs', 'Knee Replacement Pre-Op Q Score', 'Knee Replacement Post-Op Q Pain', 'Knee Replacement Post-Op Q Night Pain', 'Knee Replacement Post-Op Q Washing', 'Knee Replacement Post-Op Q Transport', 'Knee Replacement Post-Op Q Walking', 'Knee Replacement Post-Op Q Standing', 'Knee Replacement Post-Op Q Limping', 'Knee Replacement Post-Op Q Kneeling', 'Knee Replacement Post-Op Q Work', 'Knee Replacement Post-Op Q Confidence', 'Knee Replacement Post-Op Q Shopping', 'Knee Replacement Post-Op Q Stairs', 'Knee Replacement Post-Op Q Score', 'Knee Replacement OKS Post-Op Q Predicted']
#
# Columns in 1718:
# ['Provider Code', 'Procedure', 'Revision Flag', 'Year', 'Age Band', 'Gender', 'Pre-Op Q Assisted', 'Pre-Op Q Assisted By', 'Pre-Op Q Symptom Period', 'Pre-Op Q Previous Surgery', 'Pre-Op Q Living Arrangements', 'Pre-Op Q Disability', 'Heart Disease', 'High Bp', 'Stroke', 'Circulation', 'Lung Disease', 'Diabetes', 'Kidney Disease', 'Nervous System', 'Liver Disease', 'Cancer', 'Depression', 'Arthritis', 'Pre-Op Q Mobility', 'Pre-Op Q Self-Care', 'Pre-Op Q Activity', 'Pre-Op Q Discomfort', 'Pre-Op Q Anxiety', 'Pre-Op Q EQ5D Index Profile', 'Pre-Op Q EQ5D Index', 'Post-Op Q Assisted', 'Post-Op Q Assisted By', 'Post-Op Q Living Arrangements', 'Post-Op Q Disability', 'Post-Op Q Mobility', 'Post-Op Q Self-Care', 'Post-Op Q Activity', 'Post-Op Q Discomfort', 'Post-Op Q Anxiety', 'Post-Op Q Satisfaction', 'Post-Op Q Sucess', 'Post-Op Q Allergy', 'Post-Op Q Bleeding', 'Post-Op Q Wound', 'Post-Op Q Urine', 'Post-Op Q Further Surgery', 'Post-Op Q Readmitted', 'Post-Op Q EQ5D Index Profile', 'Post-Op Q EQ5D Index', 'Knee Replacement EQ 5D Index Post-Op Q Predicted', 'Pre-Op Q EQ VAS', 'Post-Op Q EQ VAS', 'Knee Replacement EQ VAS_Post-Op Q Predicted', 'Knee Replacement Pre-Op Q Pain', 'Knee Replacement Pre-Op Q Night Pain', 'Knee Replacement Pre-Op Q Washing', 'Knee Replacement Pre-Op Q Transport', 'Knee Replacement Pre-Op Q Walking', 'Knee Replacement Pre-Op Q Standing', 'Knee Replacement Pre-Op Q Limping', 'Knee Replacement Pre-Op Q Kneeling', 'Knee Replacement Pre-Op Q Work', 'Knee Replacement Pre-Op Q Confidence', 'Knee Replacement Pre-Op Q Shopping', 'Knee Replacement Pre-Op Q Stairs', 'Knee Replacement Pre-Op Q Score', 'Knee Replacement Post-Op Q Pain', 'Knee Replacement Post-Op Q Night Pain', 'Knee Replacement Post-Op Q Washing', 'Knee Replacement Post-Op Q Transport', 'Knee Replacement Post-Op Q Walking', 'Knee Replacement Post-Op Q Standing', 'Knee Replacement Post-Op Q Limping', 'Knee Replacement Post-Op Q Kneeling', 'Knee Replacement Post-Op Q Work', 'Knee Replacement Post-Op Q Confidence', 'Knee Replacement Post-Op Q Shopping', 'Knee Replacement Post-Op Q Stairs', 'Knee Replacement Post-Op Q Score', 'Knee Replacement OKS Post-Op Q Predicted']
#
# Columns in 1819:
# ['Provider Code', 'Procedure', 'Revision Flag', 'Year', 'Age Band', 'Gender', 'Pre-Op Q Assisted', 'Pre-Op Q Assisted By', 'Pre-Op Q Symptom Period', 'Pre-Op Q Previous Surgery', 'Pre-Op Q Living Arrangements', 'Pre-Op Q Disability', 'Heart Disease', 'High Bp', 'Stroke', 'Circulation', 'Lung Disease', 'Diabetes', 'Kidney Disease', 'Nervous System', 'Liver Disease', 'Cancer', 'Depression', 'Arthritis', 'Pre-Op Q Mobility', 'Pre-Op Q Self-Care', 'Pre-Op Q Activity', 'Pre-Op Q Discomfort', 'Pre-Op Q Anxiety', 'Pre-Op Q EQ5D Index Profile', 'Pre-Op Q EQ5D Index', 'Post-Op Q Assisted', 'Post-Op Q Assisted By', 'Post-Op Q Living Arrangements', 'Post-Op Q Disability', 'Post-Op Q Mobility', 'Post-Op Q Self-Care', 'Post-Op Q Activity', 'Post-Op Q Discomfort', 'Post-Op Q Anxiety', 'Post-Op Q Satisfaction', 'Post-Op Q Sucess', 'Post-Op Q Allergy', 'Post-Op Q Bleeding', 'Post-Op Q Wound', 'Post-Op Q Urine', 'Post-Op Q Further Surgery', 'Post-Op Q Readmitted', 'Post-Op Q EQ5D Index Profile', 'Post-Op Q EQ5D Index', 'Knee Replacement EQ 5D Index Post-Op Q Predicted', 'Pre-Op Q EQ VAS', 'Post-Op Q EQ VAS', 'Knee Replacement EQ VAS_Post-Op Q Predicted', 'Knee Replacement Pre-Op Q Pain', 'Knee Replacement Pre-Op Q Night Pain', 'Knee Replacement Pre-Op Q Washing', 'Knee Replacement Pre-Op Q Transport', 'Knee Replacement Pre-Op Q Walking', 'Knee Replacement Pre-Op Q Standing', 'Knee Replacement Pre-Op Q Limping', 'Knee Replacement Pre-Op Q Kneeling', 'Knee Replacement Pre-Op Q Work', 'Knee Replacement Pre-Op Q Confidence', 'Knee Replacement Pre-Op Q Shopping', 'Knee Replacement Pre-Op Q Stairs', 'Knee Replacement Pre-Op Q Score', 'Knee Replacement Post-Op Q Pain', 'Knee Replacement Post-Op Q Night Pain', 'Knee Replacement Post-Op Q Washing', 'Knee Replacement Post-Op Q Transport', 'Knee Replacement Post-Op Q Walking', 'Knee Replacement Post-Op Q Standing', 'Knee Replacement Post-Op Q Limping', 'Knee Replacement Post-Op Q Kneeling', 'Knee Replacement Post-Op Q Work', 'Knee Replacement Post-Op Q Confidence', 'Knee Replacement Post-Op Q Shopping', 'Knee Replacement Post-Op Q Stairs', 'Knee Replacement Post-Op Q Score', 'Knee Replacement OKS Post-Op Q Predicted']
#
# All columns are the same.
#
# Shape of 1617: (47604, 81)
# Shape of 1718: (45997, 81)
# Shape of 1819: (45635, 81)

# %%
# Check data types
print("Dtypes of 1617:")
print(df_1617.dtypes)
print("\nDtypes of 1718:")
print(df_1718.dtypes)
print("\nDtypes of 1819:")
print(df_1819.dtypes)
# Out:
# Dtypes of 1617:
# Provider Code                                object
# Procedure                                    object
# Revision Flag                                 int64
# Year                                         object
# Age Band                                     object
#                                              ...
# Knee Replacement Post-Op Q Confidence         int64
# Knee Replacement Post-Op Q Shopping           int64
# Knee Replacement Post-Op Q Stairs             int64
# Knee Replacement Post-Op Q Score            float64
# Knee Replacement OKS Post-Op Q Predicted    float64
# Length: 81, dtype: object
#
# Dtypes of 1718:
# Provider Code                                object
# Procedure                                    object
# Revision Flag                                 int64
# Year                                         object
# Age Band                                     object
#                                              ...
# Knee Replacement Post-Op Q Confidence         int64
# Knee Replacement Post-Op Q Shopping           int64
# Knee Replacement Post-Op Q Stairs             int64
# Knee Replacement Post-Op Q Score            float64
# Knee Replacement OKS Post-Op Q Predicted    float64
# Length: 81, dtype: object
#
# Dtypes of 1819:
# Provider Code                                object
# Procedure                                    object
# Revision Flag                                 int64
# Year                                         object
# Age Band                                     object
#                                              ...
# Knee Replacement Post-Op Q Confidence         int64
# Knee Replacement Post-Op Q Shopping           int64
# Knee Replacement Post-Op Q Stairs             int64
# Knee Replacement Post-Op Q Score            float64
# Knee Replacement OKS Post-Op Q Predicted    float64
# Length: 81, dtype: object

# %%
# Sample data
print("Head of 1617:")
print(df_1617.head())
print("\nHead of 1718:")
print(df_1718.head())
print("\nHead of 1819:")
print(df_1819.head())
# Out:
# Head of 1617:
#   Provider Code         Procedure  Revision Flag     Year Age Band Gender  \
# 0         ADP02  Knee Replacement              0  2016/17        *      *
# 1         ADP02  Knee Replacement              0  2016/17        *      *
# 2         ADP02  Knee Replacement              0  2016/17        *      *
# 3         ADP02  Knee Replacement              0  2016/17        *      *
# 4         ADP02  Knee Replacement              0  2016/17        *      *
#
#    Pre-Op Q Assisted  Pre-Op Q Assisted By  Pre-Op Q Symptom Period  \
# 0                  2                     0                        4
# 1                  2                     0                        1
# 2                  2                     0                        2
# 3                  2                     0                        2
# 4                  1                     0                        3
#
#    Pre-Op Q Previous Surgery  ...  Knee Replacement Post-Op Q Walking  \
# 0                          2  ...                                   2
# 1                          2  ...                                   4
# 2                          2  ...                                   4
# 3                          2  ...                                   4
# 4                          2  ...                                   3
#
#    Knee Replacement Post-Op Q Standing  Knee Replacement Post-Op Q Limping  \
# 0                                    2                                   3
# 1                                    4                                   4
# 2                                    4                                   4
# 3                                    4                                   3
# 4                                    4                                   2
#
#    Knee Replacement Post-Op Q Kneeling  Knee Replacement Post-Op Q Work  \
# 0                                    2                                3
# 1                                    2                                4
# 2                                    3                                4
# 3                                    4                                4
# 4                                    2                                2
#
#    Knee Replacement Post-Op Q Confidence  Knee Replacement Post-Op Q Shopping  \
# 0                                      1                                    3
# 1                                      4                                    4
# 2                                      4                                    4
# 3                                      4                                    4
# 4                                      4                                    2
#
#    Knee Replacement Post-Op Q Stairs  Knee Replacement Post-Op Q Score  \
# 0                                  2                              29.0
# 1                                  3                              39.0
# 2                                  4                              45.0
# 3                                  4                              43.0
# 4                                  3                              36.0
#
#    Knee Replacement OKS Post-Op Q Predicted
# 0                                 28.123754
# 1                                 39.592750
# 2                                 40.250789
# 3                                 37.896225
# 4                                 40.142566
#
# [5 rows x 81 columns]
#
# Head of 1718:
#   Provider Code         Procedure  Revision Flag     Year Age Band Gender  \
# 0         ADP02  Knee Replacement              0  2017/18        *      *
# 1         ADP02  Knee Replacement              0  2017/18        *      *
# 2         ADP02  Knee Replacement              0  2017/18        *      *
# 3         ADP02  Knee Replacement              0  2017/18        *      *
# 4         ADP02  Knee Replacement              0  2017/18        *      *
#
#    Pre-Op Q Assisted  Pre-Op Q Assisted By  Pre-Op Q Symptom Period  \
# 0                  1                     0                        2
# 1                  2                     0                        4
# 2                  2                     0                        3
# 3                  2                     0                        4
# 4                  1                     0                        2
#
#    Pre-Op Q Previous Surgery  ...  Knee Replacement Post-Op Q Walking  \
# 0                          2  ...                                   4
# 1                          2  ...                                   4
# 2                          2  ...                                   4
# 3                          2  ...                                   4
# 4                          2  ...                                   4
#
#    Knee Replacement Post-Op Q Standing  Knee Replacement Post-Op Q Limping  \
# 0                                    4                                   4
# 1                                    4                                   3
# 2                                    4                                   4
# 3                                    3                                   3
# 4                                    4                                   4
#
#    Knee Replacement Post-Op Q Kneeling  Knee Replacement Post-Op Q Work  \
# 0                                    0                                4
# 1                                    4                                4
# 2                                    4                                4
# 3                                    3                                4
# 4                                    4                                4
#
#    Knee Replacement Post-Op Q Confidence  Knee Replacement Post-Op Q Shopping  \
# 0                                      4                                    4
# 1                                      4                                    4
# 2                                      4                                    4
# 3                                      4                                    4
# 4                                      4                                    4
#
#    Knee Replacement Post-Op Q Stairs  Knee Replacement Post-Op Q Score  \
# 0                                  4                              44.0
# 1                                  4                              46.0
# 2                                  3                              45.0
# 3                                  4                              43.0
# 4                                  4                               NaN
#
#    Knee Replacement OKS Post-Op Q Predicted
# 0                                 31.794286
# 1                                 34.125352
# 2                                 30.674794
# 3                                 35.714185
# 4                                       NaN
#
# [5 rows x 81 columns]
#
# Head of 1819:
#   Provider Code         Procedure  Revision Flag     Year Age Band Gender  \
# 0         ADP02  Knee Replacement              0  2018/19        *      *
# 1         ADP02  Knee Replacement              0  2018/19        *      *
# 2         ADP02  Knee Replacement              0  2018/19        *      *
# 3         ADP02  Knee Replacement              0  2018/19        *      *
# 4         ADP02  Knee Replacement              0  2018/19        *      *
#
#    Pre-Op Q Assisted  Pre-Op Q Assisted By  Pre-Op Q Symptom Period  \
# 0                  2                     0                        2
# 1                  2                     0                        2
# 2                  2                     0                        2
# 3                  2                     0                        2
# 4                  1                     0                        3
#
#    Pre-Op Q Previous Surgery  ...  Knee Replacement Post-Op Q Walking  \
# 0                          2  ...                                   3
# 1                          2  ...                                   4
# 2                          2  ...                                   4
# 3                          2  ...                                   1
# 4                          2  ...                                   2
#
#    Knee Replacement Post-Op Q Standing  Knee Replacement Post-Op Q Limping  \
# 0                                    3                                   4
# 1                                    4                                   4
# 2                                    4                                   4
# 3                                    4                                   4
# 4                                    3                                   3
#
#    Knee Replacement Post-Op Q Kneeling  Knee Replacement Post-Op Q Work  \
# 0                                    2                                4
# 1                                    3                                3
# 2                                    2                                4
# 3                                    1                                3
# 4                                    2                                2
#
#    Knee Replacement Post-Op Q Confidence  Knee Replacement Post-Op Q Shopping  \
# 0                                      4                                    4
# 1                                      3                                    4
# 2                                      4                                    4
# 3                                      3                                    4
# 4                                      3                                    2
#
#    Knee Replacement Post-Op Q Stairs  Knee Replacement Post-Op Q Score  \
# 0                                  3                              40.0
# 1                                  4                              44.0
# 2                                  4                              46.0
# 3                                  3                              36.0
# 4                                  1                              28.0
#
#    Knee Replacement OKS Post-Op Q Predicted
# 0                                 34.825797
# 1                                 43.180367
# 2                                 42.201863
# 3                                 36.826899
# 4                                 33.434301
#
# [5 rows x 81 columns]

# %%
# Check for missing values
print("Missing values in 1617:")
print(df_1617.isnull().sum())
print("\nMissing values in 1718:")
print(df_1718.isnull().sum())
print("\nMissing values in 1819:")
print(df_1819.isnull().sum())
# Out:
# Missing values in 1617:
# Provider Code                                  0
# Procedure                                      0
# Revision Flag                                  0
# Year                                           0
# Age Band                                       0
#                                             ...
# Knee Replacement Post-Op Q Confidence          0
# Knee Replacement Post-Op Q Shopping            0
# Knee Replacement Post-Op Q Stairs              0
# Knee Replacement Post-Op Q Score             645
# Knee Replacement OKS Post-Op Q Predicted    1491
# Length: 81, dtype: int64
#
# Missing values in 1718:
# Provider Code                                  0
# Procedure                                      0
# Revision Flag                                  0
# Year                                           0
# Age Band                                       0
#                                             ...
# Knee Replacement Post-Op Q Confidence          0
# Knee Replacement Post-Op Q Shopping            0
# Knee Replacement Post-Op Q Stairs              0
# Knee Replacement Post-Op Q Score            1145
# Knee Replacement OKS Post-Op Q Predicted    2091
# Length: 81, dtype: int64
#
# Missing values in 1819:
# Provider Code                                  0
# Procedure                                      0
# Revision Flag                                  0
# Year                                           0
# Age Band                                       0
#                                             ...
# Knee Replacement Post-Op Q Confidence          0
# Knee Replacement Post-Op Q Shopping            0
# Knee Replacement Post-Op Q Stairs              0
# Knee Replacement Post-Op Q Score             789
# Knee Replacement OKS Post-Op Q Predicted    1799
# Length: 81, dtype: int64

# %%
# Since columns are the same, add year and concatenate
df_1617['CSVYear'] = '2016/17'
df_1718['CSVYear'] = '2017/18'
df_1819['CSVYear'] = '2018/19'

# Concatenate
merged_df = pd.concat([df_1617, df_1718, df_1819], ignore_index=True)
print("Merged shape:", merged_df.shape)
print("Merged columns:", list(merged_df.columns))
# Out:
# Merged shape: (139236, 82)
# Merged columns: ['Provider Code', 'Procedure', 'Revision Flag', 'Year', 'Age Band', 'Gender', 'Pre-Op Q Assisted', 'Pre-Op Q Assisted By', 'Pre-Op Q Symptom Period', 'Pre-Op Q Previous Surgery', 'Pre-Op Q Living Arrangements', 'Pre-Op Q Disability', 'Heart Disease', 'High Bp', 'Stroke', 'Circulation', 'Lung Disease', 'Diabetes', 'Kidney Disease', 'Nervous System', 'Liver Disease', 'Cancer', 'Depression', 'Arthritis', 'Pre-Op Q Mobility', 'Pre-Op Q Self-Care', 'Pre-Op Q Activity', 'Pre-Op Q Discomfort', 'Pre-Op Q Anxiety', 'Pre-Op Q EQ5D Index Profile', 'Pre-Op Q EQ5D Index', 'Post-Op Q Assisted', 'Post-Op Q Assisted By', 'Post-Op Q Living Arrangements', 'Post-Op Q Disability', 'Post-Op Q Mobility', 'Post-Op Q Self-Care', 'Post-Op Q Activity', 'Post-Op Q Discomfort', 'Post-Op Q Anxiety', 'Post-Op Q Satisfaction', 'Post-Op Q Sucess', 'Post-Op Q Allergy', 'Post-Op Q Bleeding', 'Post-Op Q Wound', 'Post-Op Q Urine', 'Post-Op Q Further Surgery', 'Post-Op Q Readmitted', 'Post-Op Q EQ5D Index Profile', 'Post-Op Q EQ5D Index', 'Knee Replacement EQ 5D Index Post-Op Q Predicted', 'Pre-Op Q EQ VAS', 'Post-Op Q EQ VAS', 'Knee Replacement EQ VAS_Post-Op Q Predicted', 'Knee Replacement Pre-Op Q Pain', 'Knee Replacement Pre-Op Q Night Pain', 'Knee Replacement Pre-Op Q Washing', 'Knee Replacement Pre-Op Q Transport', 'Knee Replacement Pre-Op Q Walking', 'Knee Replacement Pre-Op Q Standing', 'Knee Replacement Pre-Op Q Limping', 'Knee Replacement Pre-Op Q Kneeling', 'Knee Replacement Pre-Op Q Work', 'Knee Replacement Pre-Op Q Confidence', 'Knee Replacement Pre-Op Q Shopping', 'Knee Replacement Pre-Op Q Stairs', 'Knee Replacement Pre-Op Q Score', 'Knee Replacement Post-Op Q Pain', 'Knee Replacement Post-Op Q Night Pain', 'Knee Replacement Post-Op Q Washing', 'Knee Replacement Post-Op Q Transport', 'Knee Replacement Post-Op Q Walking', 'Knee Replacement Post-Op Q Standing', 'Knee Replacement Post-Op Q Limping', 'Knee Replacement Post-Op Q Kneeling', 'Knee Replacement Post-Op Q Work', 'Knee Replacement Post-Op Q Confidence', 'Knee Replacement Post-Op Q Shopping', 'Knee Replacement Post-Op Q Stairs', 'Knee Replacement Post-Op Q Score', 'Knee Replacement OKS Post-Op Q Predicted', 'CSVYear']

# %%
# Check for duplicates
duplicates = merged_df.duplicated()
print("Number of duplicate rows:", duplicates.sum())
if duplicates.sum() > 0:
    print("Duplicate rows:")
    print(merged_df[duplicates].head())
# Out:
# Number of duplicate rows: 0

# %%
# Save the merged dataframe
merged_path = '../merged/Knee Replacement Provider.csv'
merged_df.to_csv(merged_path, index=False)
print(f"Merged data saved to {merged_path}")
# Out:
# Merged data saved to ../merged/Knee Replacement Provider.csv
