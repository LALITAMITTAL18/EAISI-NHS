# %% [markdown]
# # PartLink Hip and Knee Replacement Data Merging
#
# This notebook loads and merges the PartLink Hip and Knee Replacement data from 2016/17, 2017/18, and 2018/19.

# %%
import pandas as pd
import os

# %%
# Define file paths
files = {
    "1617": "../external/PartLink Hip and Knee Replacement 1617.csv",
    "1718": "../external/PartLink Hip and Knee Replacements 1718.csv",
    "1819": "../external/PartLink Hip and Knee Replacement 1819.csv"
}

# Load dataframes with appropriate separators
df_1617 = pd.read_csv(files["1617"], sep=',')
df_1718 = pd.read_csv(files["1718"], sep=',')
df_1819 = pd.read_csv(files["1819"], sep=',')

# %%
# Check columns
print("Columns in 1617:")
print(df_1617.columns.tolist())
print("\nColumns in 1718:")
print(df_1718.columns.tolist())
print("\nColumns in 1819:")
print(df_1819.columns.tolist())

# Check if columns are the same
cols_1617 = set(df_1617.columns)
cols_1718 = set(df_1718.columns)
cols_1819 = set(df_1819.columns)

if cols_1617 == cols_1718 == cols_1819:
    print("\nAll columns are the same.")
else:
    print("\nColumns differ:")
    print("Unique to 1617:", cols_1617 - cols_1718 - cols_1819)
    print("Unique to 1718:", cols_1718 - cols_1617 - cols_1819)
    print("Unique to 1819:", cols_1819 - cols_1617 - cols_1718)

# Check shapes
print("\nShape of 1617:", df_1617.shape)
print("Shape of 1718:", df_1718.shape)
print("Shape of 1819:", df_1819.shape)
# Out:
# Columns in 1617:
# ['Organisation Code', 'Organisation Name', 'All Procedures - Total HES Procedures', 'All Procedures - Total Pre-Op Qs', 'All Procedures - Participation Rate', 'All Procedures - Total Linked', 'All Procedures - Linkage rate', 'All Procedures - Total Q2s sent to date', 'All Procedures - Issue rate', 'All Procedures - Total Q2s returned to date', 'All Procedures - Response rate', 'Hip Replacement - Total HES Procedures', 'Hip Replacement - Total Pre-Op Qs', 'Hip Replacement - Participation Rate', 'Hip Replacement - Total Linked', 'Hip Replacement - Linkage rate', 'Hip Replacement - Total Q2s sent to date', 'Hip Replacement - Issue rate', 'Hip Replacement - Total Q2s returned to date', 'Hip Replacement - Response rate', 'Primary Hip Replacement - Total HES Procedures', 'Primary Hip Replacement - Total Pre-Op Qs', 'Primary Hip Replacement - Participation Rate', 'Primary Hip Replacement - Total Linked', 'Primary Hip Replacement - Linkage rate', 'Primary Hip Replacement - Total Q2s sent to date', 'Primary Hip Replacement - Issue rate', 'Primary Hip Replacement - Total Q2s returned to date', 'Primary Hip Replacement - Response rate', 'Revision Hip Replacement - Total HES Procedures', 'Revision Hip Replacement - Total Pre-Op Qs', 'Revision Hip Replacement - Participation Rate', 'Revision Hip Replacement - Total Linked', 'Revision Hip Replacement - Linkage rate', 'Revision Hip Replacement - Total Q2s sent to date', 'Revision Hip Replacement - Issue rate', 'Revision Hip Replacement - Total Q2s returned to date', 'Revision Hip Replacement - Response rate', 'Knee Replacement - Total HES Procedures', 'Knee Replacement - Total Pre-Op Qs', '
#
# All columns are the same.
#
# Shape of 1617: (312, 65)
# Shape of 1718: (314, 65)
# Shape of 1819: (317, 65)

# %%
# Check data types
print("Dtypes of 1617:")
print(df_1617.dtypes)
print("\nDtypes of 1718:")
print(df_1718.dtypes)
print("\nDtypes of 1819:")
print(df_1819.dtypes)
# Out:
# Dtypes of 1617:
# Organisation Code                                          object
# Organisation Name                                          object
# All Procedures - Total HES Procedures                       int64
# All Procedures - Total Pre-Op Qs                            int64
# All Procedures - Participation Rate                       float64
#                                                            ...
# Revision Knee Replacement - Total Q2s sent to date         object
# Revision Knee Replacement - Issue rate                     object
# Revision Knee Replacement - Total Q2s returned to date     object
# Revision Knee Replacement - Response rate                  object
# CSVYear                                                    object
# Length: 66, dtype: object
#
# Dtypes of 1718:
# Organisation Code                                          object
# Organisation Name                                          object
# All Procedures - Total HES Procedures                       int64
# All Procedures - Total Pre-Op Qs                            int64
# All Procedures - Participation Rate                       float64
#                                                            ...
# Revision Knee Replacement - Total Q2s sent to date         object
# Revision Knee Replacement - Issue rate                     object
# Revision Knee Replacement - Total Q2s returned to date     object
# Revision Knee Replacement - Response rate                  object
# CSVYear                                                    object
# Length: 66, dtype: object
#
# Dtypes of 1819:
# Organisation Code                                          object
# Organisation Name                                          object
# All Procedures - Total HES Procedures                       int64
# All Procedures - Total Pre-Op Qs                            int64
# All Procedures - Participation Rate                       float64
#                                                            ...
# Revision Knee Replacement - Total Q2s sent to date         object
# Revision Knee Replacement - Issue rate                     object
# Revision Knee Replacement - Total Q2s returned to date     object
# Revision Knee Replacement - Response rate                  object
# CSVYear                                                    object
# Length: 66, dtype: object

# %%
# Sample data
print("Head of 1617:")
print(df_1617.head())
print("\nHead of 1718:")
print(df_1718.head())
print("\nHead of 1819:")
print(df_1819.head())
# Out:
# Head of 1617:
#   Organisation Code                                  Organisation Name  \
# 0           England                                            ENGLAND
# 1               REM   AINTREE UNIVERSITY HOSPITAL NHS FOUNDATION TRUST
# 2               RCF                      AIREDALE NHS FOUNDATION TRUST
# 3               RTK  ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATIO...
# 4             NVC01                                   ASHTEAD HOSPITAL
#
#    All Procedures - Total HES Procedures  All Procedures - Total Pre-Op Qs  \
# 0                                 169114                            153425
# 1                                    632                               627
# 2                                    449                               444
# 3                                    784                               966
# 4                                    155                               171
#
#    All Procedures - Participation Rate  All Procedures - Total Linked  \
# 0                             0.907228                         116021
# 1                             0.992089                            430
# 2                             0.988864                            384
# 3                             1.232143                            690
# 4                             1.103226                            136
#
#    All Procedures - Linkage rate  All Procedures - Total Q2s sent to date  \
# 0                       0.756207                                   148927
# 1                       0.685805                                      620
# 2                       0.864865                                      441
# 3                       0.714286                                      893
# 4                       0.795322                                      171
#
#    All Procedures - Issue rate  All Procedures - Total Q2s returned to date  \
# 0                     0.970683                                       112848
# 1                     0.988836                                          359
# 2                     0.993243                                          365
# 3                     0.924431                                          656
# 4                     1.000000                                          146
#
#    ...  Revision Knee Replacement - Total HES Procedures  \
# 0  ...                                              4959
# 1  ...                                                29
# 2  ...                                                 *
# 3  ...                                                29
# 4  ...                                                 *
#
#   Revision Knee Replacement - Total Pre-Op Qs  \
# 0                                        2489
# 1                                          13
# 2                                           *
# 3                                          22
# 4                                           0
#
#   Revision Knee Replacement - Participation Rate  \
# 0                                      0.5019157
# 1                                      0.4482759
# 2                                              *
# 3                                      0.7586207
# 4                                              *
#
#   Revision Knee Replacement - Total Linked  \
# 0                                     2489
# 1                                       13
# 2                                        *
# 3                                       22
# 4                                        0
#
#   Revision Knee Replacement - Linkage rate  \
# 0                                        1
# 1                                        1
# 2                                        *
# 3                                        1
# 4                                        0
#
#   Revision Knee Replacement - Total Q2s sent to date  \
# 0                                               2439
# 1                                                 13
# 2                                                  *
# 3                                                 21
# 4                                                  0
#
#   Revision Knee Replacement - Issue rate  \
# 0                              0.9799116
# 1                                      1
# 2                                      *
# 3                              0.9545455
# 4                                      0
#
#   Revision Knee Replacement - Total Q2s returned to date  \
# 0                                               1795
# 1                                                  9
# 2                                                  *
# 3                                                 16
# 4                                                  0
#
#   Revision Knee Replacement - Response rate  CSVYear
# 0                                 0.7359574  2016/17
# 1                                 0.6923077  2016/17
# 2                                         *  2016/17
# 3                                 0.7619048  2016/17
# 4                                         0  2016/17
#
# [5 rows x 66 columns]
#
# Head of 1718:
#   Organisation Code                                  Organisation Name  \
# 0           England                                            ENGLAND
# 1               REM   AINTREE UNIVERSITY HOSPITAL NHS FOUNDATION TRUST
# 2               RCF                      AIREDALE NHS FOUNDATION TRUST
# 3               RTK  ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATIO...
# 4             NVC01                                   ASHTEAD HOSPITAL
#
#    All Procedures - Total HES Procedures  All Procedures - Total Pre-Op Qs  \
# 0                                 166722                            144618
# 1                                    542                               377
# 2                                    471                               424
# 3                                    691                               778
# 4                                     74                                84
#
#    All Procedures - Participation Rate  All Procedures - Total Linked  \
# 0                             0.867420                         109093
# 1                             0.695572                            235
# 2                             0.900212                            376
# 3                             1.125905                            480
# 4                             1.135135                             62
#
#    All Procedures - Linkage rate  All Procedures - Total Q2s sent to date  \
# 0                       0.754353                                   137574
# 1                       0.623342                                      376
# 2                       0.886792                                      420
# 3                       0.616967                                      687
# 4                       0.738095                                       82
#
#    All Procedures - Issue rate  All Procedures - Total Q2s returned to date  \
# 0                     0.951292                                        96501
# 1                     0.997348                                          216
# 2                     0.990566                                          327
# 3                     0.883033                                          410
# 4                     0.976190                                           71
#
#    ...  Revision Knee Replacement - Total HES Procedures  \
# 0  ...                                              4969
# 1  ...                                                20
# 2  ...                                                 6
# 3  ...                                                27
# 4  ...                                                 *
#
#   Revision Knee Replacement - Total Pre-Op Qs  \
# 0                                        2524
# 1                                           7
# 2                                           *
# 3                                          13
# 4                                           *
#
#   Revision Knee Replacement - Participation Rate  \
# 0                                      0.5079493
# 1                                           0.35
# 2                                              *
# 3                                      0.4814815
# 4                                              *
#
#   Revision Knee Replacement - Total Linked  \
# 0                                     2524
# 1                                        7
# 2                                        *
# 3                                       13
# 4                                        *
#
#   Revision Knee Replacement - Linkage rate  \
# 0                                        1
# 1                                        1
# 2                                        *
# 3                                        1
# 4                                        *
#
#   Revision Knee Replacement - Total Q2s sent to date  \
# 0                                               2485
# 1                                                  7
# 2                                                  *
# 3                                                 12
# 4                                                  *
#
#   Revision Knee Replacement - Issue rate  \
# 0                              0.9845483
# 1                                      1
# 2                                      *
# 3                              0.9230769
# 4                                      *
#
#   Revision Knee Replacement - Total Q2s returned to date  \
# 0                                               1721
# 1                                                  5
# 2                                                  *
# 3                                                  7
# 4                                                  0
#
#   Revision Knee Replacement - Response rate  CSVYear
# 0                                 0.6925553  2017/18
# 1                                 0.7142857  2017/18
# 2                                         *  2017/18
# 3                                 0.5833333  2017/18
# 4                                         *  2017/18
#
# [5 rows x 66 columns]
#
# Head of 1819:
#   Organisation Code                                  Organisation Name  \
# 0           England                                            ENGLAND
# 1               RCF                      AIREDALE NHS FOUNDATION TRUST
# 2               RBS          ALDER HEY CHILDREN'S NHS FOUNDATION TRUST
# 3               RTK  ASHFORD AND ST PETER'S HOSPITALS NHS FOUNDATIO...
# 4             NVC01                                   ASHTEAD HOSPITAL
#
#    All Procedures - Total HES Procedures  All Procedures - Total Pre-Op Qs  \
# 0                                 175041                            150340
# 1                                    445                               361
# 2                                      0                                 0
# 3                                    849                               755
# 4                                     82                                83
#
#    All Procedures - Participation Rate  All Procedures - Total Linked  \
# 0                             0.858885                         117142
# 1                             0.811236                            321
# 2                             0.000000                              0
# 3                             0.889281                            543
# 4                             1.012195                             66
#
#    All Procedures - Linkage rate  All Procedures - Total Q2s sent to date  \
# 0                       0.779181                                   139953
# 1                       0.889197                                      359
# 2                       0.000000                                        0
# 3                       0.719205                                      694
# 4                       0.795181                                       83
#
#    All Procedures - Issue rate  All Procedures - Total Q2s returned to date  \
# 0                     0.930910                                        97545
# 1                     0.994460                                          270
# 2                     0.000000                                            0
# 3                     0.919205                                          409
# 4                     1.000000                                           60
#
#    ...  Revision Knee Replacement - Total HES Procedures  \
# 0  ...                                              5001
# 1  ...                                                 9
# 2  ...                                                 0
# 3  ...                                                22
# 4  ...                                                 *
#
#   Revision Knee Replacement - Total Pre-Op Qs  \
# 0                                        2419
# 1                                           *
# 2                                           0
# 3                                          13
# 4                                           *
#
#   Revision Knee Replacement - Participation Rate  \
# 0                                      0.4837033
# 1                                              *
# 2                                              0
# 3                                      0.5909091
# 4                                              *
#
#   Revision Knee Replacement - Total Linked  \
# 0                                     2419
# 1                                        *
# 2                                        0
# 3                                       13
# 4                                        *
#
#   Revision Knee Replacement - Linkage rate  \
# 0                                        1
# 1                                        *
# 2                                        0
# 3                                        1
# 4                                        *
#
#   Revision Knee Replacement - Total Q2s sent to date  \
# 0                                               2355
# 1                                                  *
# 2                                                  0
# 3                                                 12
# 4                                                  *
#
#   Revision Knee Replacement - Issue rate  \
# 0                              0.9735428
# 1                                      *
# 2                                      0
# 3                              0.9230769
# 4                                      *
#
#   Revision Knee Replacement - Total Q2s returned to date  \
# 0                                               1596
# 1                                                  *
# 2                                                  0
# 3                                                  8
# 4                                                  *
#
#   Revision Knee Replacement - Response rate  CSVYear
# 0                                  0.677707  2018/19
# 1                                         *  2018/19
# 2                                         0  2018/19
# 3                                 0.6666667  2018/19
# 4                                         *  2018/19
#
# [5 rows x 66 columns]

# %%
# Check for missing values
print("Missing values in 1617:")
print(df_1617.isnull().sum())
print("\nMissing values in 1718:")
print(df_1718.isnull().sum())
print("\nMissing values in 1819:")
print(df_1819.isnull().sum())
# Out:
# Missing values in 1617:
# Organisation Code                                         0
# Organisation Name                                         0
# All Procedures - Total HES Procedures                     0
# All Procedures - Total Pre-Op Qs                          0
# All Procedures - Participation Rate                       0
#                                                          ..
# Revision Knee Replacement - Total Q2s sent to date        0
# Revision Knee Replacement - Issue rate                    0
# Revision Knee Replacement - Total Q2s returned to date    0
# Revision Knee Replacement - Response rate                 0
# CSVYear                                                   0
# Length: 66, dtype: int64
#
# Missing values in 1718:
# Organisation Code                                         0
# Organisation Name                                         0
# All Procedures - Total HES Procedures                     0
# All Procedures - Total Pre-Op Qs                          0
# All Procedures - Participation Rate                       0
#                                                          ..
# Revision Knee Replacement - Total Q2s sent to date        0
# Revision Knee Replacement - Issue rate                    0
# Revision Knee Replacement - Total Q2s returned to date    0
# Revision Knee Replacement - Response rate                 0
# CSVYear                                                   0
# Length: 66, dtype: int64
#
# Missing values in 1819:
# Organisation Code                                         0
# Organisation Name                                         0
# All Procedures - Total HES Procedures                     0
# All Procedures - Total Pre-Op Qs                          0
# All Procedures - Participation Rate                       0
#                                                          ..
# Revision Knee Replacement - Total Q2s sent to date        0
# Revision Knee Replacement - Issue rate                    0
# Revision Knee Replacement - Total Q2s returned to date    0
# Revision Knee Replacement - Response rate                 0
# CSVYear                                                   0
# Length: 66, dtype: int64

# %%
# Since columns are the same, add year and concatenate
df_1617['CSVYear'] = '2016/17'
df_1718['CSVYear'] = '2017/18'
df_1819['CSVYear'] = '2018/19'

# Concatenate
merged_df = pd.concat([df_1617, df_1718, df_1819], ignore_index=True)
print("Merged shape:", merged_df.shape)
print("Merged columns:", list(merged_df.columns))
# Out:
# Merged shape: (943, 66)
# Merged columns: ['Organisation Code', 'Organisation Name', 'All Procedures - Total HES Procedures', 'All Procedures - Total Pre-Op Qs', 'All Procedures - Participation Rate', 'All Procedures - Total Linked', 'All Procedures - Linkage rate', 'All Procedures - Total Q2s sent to date', 'All Procedures - Issue rate', 'All Procedures - Total Q2s returned to date', 'All Procedures - Response rate', 'Hip Replacement - Total HES Procedures', 'Hip Replacement - Total Pre-Op Qs', 'Hip Replacement - Participation Rate', 'Hip Replacement - Total Linked', 'Hip Replacement - Linkage rate', 'Hip Replacement - Total Q2s sent to date', 'Hip Replacement - Issue rate', 'Hip Replacement - Total Q2s returned to date', 'Hip Replacement - Response rate', 'Primary Hip Replacement - Total HES Procedures', 'Primary Hip Replacement - Total Pre-Op Qs', 'Primary Hip Replacement - Participation Rate', 'Primary Hip Replacement - Total Linked', 'Primary Hip Replacement - Linkage rate', 'Primary Hip Replacement - Total Q2s sent to date', 'Primary Hip Replacement - Issue rate', 'Primary Hip Replacement - Total Q2s returned to date', 'Primary Hip Replacement - Response rate', 'Revision Hip Replacement - Total HES Procedures', 'Revision Hip Replacement - Total Pre-Op Qs', 'Revision Hip Replacement - Participation Rate', 'Revision Hip Replacement - Total Linked', 'Revision Hip Replacement - Linkage rate', 'Revision Hip Replacement - Total Q2s sent to date', 'Revision Hip Replacement - Issue rate', 'Revision Hip Replacement - Total Q2s returned to date', 'Revision Hip Replacement - Response rate', 'Knee Replacement - Total HES Procedures', 'Knee Replacement - Total Pre-Op Qs', 'Knee Replacement - Participation Rate', 'Knee Replacement - Total Linked', 'Knee Replacement - Linkage rate', 'Knee Replacement - Total Q2s sent to date', 'Knee Replacement - Issue rate', 'Knee Replacement - Total Q2s returned to date', 'Knee Replacement - Response rate', 'Primary Knee Replacement - Total HES Procedures', 'Primary Knee Replacement - Total Pre-Op Qs', 'Primary Knee Replacement - Participation Rate', 'Primary Knee Replacement - Total Linked', 'Primary Knee Replacement - Linkage rate', 'Primary Knee Replacement - Total Q2s sent to date', 'Primary Knee Replacement - Issue rate', 'Primary Knee Replacement - Total Q2s returned to date', 'Primary Knee Replacement - Response rate', 'Revision Knee Replacement - Total HES Procedures', 'Revision Knee Replacement - Total Pre-Op Qs', 'Revision Knee Replacement - Participation Rate', 'Revision Knee Replacement - Total Linked', 'Revision Knee Replacement - Linkage rate', 'Revision Knee Replacement - Total Q2s sent to date', 'Revision Knee Replacement - Issue rate', 'Revision Knee Replacement - Total Q2s returned to date', 'Revision Knee Replacement - Response rate', 'CSVYear']

# %%
# Check for duplicates
duplicates = merged_df.duplicated()
print("Number of duplicate rows:", duplicates.sum())
if duplicates.sum() > 0:
    print("Duplicate rows:")
    print(merged_df[duplicates].head())
# Out:
# Number of duplicate rows: 0

# %%
# Save the merged dataframe
merged_path = '../merged/PartLink Hip and Knee Replacement.csv'
merged_df.to_csv(merged_path, index=False)
print(f"Merged data saved to {merged_path}")
# Out:
# Merged data saved to ../merged/PartLink Hip and Knee Replacement.csv
