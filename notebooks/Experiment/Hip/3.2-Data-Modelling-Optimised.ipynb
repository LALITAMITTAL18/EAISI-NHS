# %% [markdown]
# # 3.3 — Optimised Regression Modelling (Bayesian HPO + Stacking)
#
# This notebook follows the same **dataset × model** structure as `3.1` but replaces fixed hyperparameters
# with **Bayesian optimisation via Optuna** and adds a **StackingRegressor** ensemble.
#
# Works with all three prepared datasets including the new **2.4** (feature-engineered):
#
# | Dataset | Source notebook | Key additions |
# |---|---|---|
# | 2.1-Manual | 2.1 | Listwise deletion |
# | 2.2-UMAP-MICE | 2.2 | MICE imputation, UMAP clustering |
# | **2.4-FeatEng** | **2.4** | **Feature engineering + year-based split** |
#
# Results are saved to `./models/3.3-all_results_cache.joblib` so they can be compared
# side-by-side with `3.1`'s `./models/all_results_cache.joblib` in Section 7.
#
# ## Outline
#
# | # | Section |
# |---|---|
# | 1 | Imports & Global Setup |
# | 2 | Pipeline Helpers |
# | 3 | Load All Datasets |
# | 4 | Bayesian HPO — Search Spaces & `tune_and_run()` |
# | 5 | Individual Tuned Runs — one cell per model |
# | 6 | Stacking Ensemble |
# | 7 | Full Comparison (3.3 results + vs 3.1 baseline) |
# | 8 | CV vs Test RMSE Gap — Overfitting Diagnostic |

# %% [markdown]
# ## 1. Imports & Global Setup

# %%
import subprocess, sys

_packages = [
    'polars', 'scikit-learn', 'xgboost', 'catboost', 'interpret', 'shap',
    'joblib', 'matplotlib', 'seaborn', 'jinja2',
    'numpy', 'pandas', 'optuna',
]
for pkg in _packages:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '--quiet', pkg])

print('All dependencies installed (including optuna, catboost, and interpret).')
# Out:
# All dependencies installed (including optuna, catboost, and interpret).

# %%
from pathlib import Path

import polars as pl
import numpy as np
import pandas as pd
import joblib

from sklearn.model_selection import (
    RepeatedKFold, KFold, GroupKFold,
    cross_validate, cross_val_score,
)
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import (
    RandomForestRegressor,
    HistGradientBoostingRegressor,
    StackingRegressor,
)
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.base import clone

import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

try:
    from xgboost import XGBRegressor
    _xgb_available = True
except ImportError:
    _xgb_available = False

try:
    from catboost import CatBoostRegressor
    _catboost_available = True
except ImportError:
    _catboost_available = False

try:
    from interpret.glassbox import ExplainableBoostingRegressor
    _ebm_available = True
except ImportError:
    _ebm_available = False

import matplotlib.pyplot as plt
import seaborn as sns

print(f'Libraries loaded.')
print(f'  XGBoost  : {_xgb_available}')
print(f'  CatBoost : {_catboost_available}')
print(f'  EBM      : {_ebm_available}')
print(f'  MLP      : True (sklearn built-in)')
# Out:
# Libraries loaded.
#   XGBoost  : True
#   CatBoost : True
#   EBM      : True
#   MLP      : True (sklearn built-in)

# %% [markdown]
# ## 2. Pipeline Helpers
#
# Refactored from 3.1: `build_preprocessor()` is extracted so Optuna can reuse it inside the objective
# without rebuilding the full pipeline each trial. The preprocessor is fitted **once** per `tune_and_run()` call,
# and the tuned model is fitted on the pre-transformed arrays for speed.

# %%
_NUMERIC_DTYPES = {
    pl.Int8,  pl.Int16,  pl.Int32,  pl.Int64,
    pl.UInt8, pl.UInt16, pl.UInt32, pl.UInt64,
    pl.Float32, pl.Float64,
}
_STRING_DTYPES = {pl.Utf8, pl.String, pl.Categorical}


def build_preprocessor(numeric_cols: list, cat_cols: list) -> ColumnTransformer:
    """Build a ColumnTransformer with median imputation + scaling / one-hot."""
    numeric_transformer = Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler',  StandardScaler()),
    ])
    transformers = []
    if numeric_cols:
        transformers.append(('num', numeric_transformer, numeric_cols))
    if cat_cols:
        cat_transformer = Pipeline([
            ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
            ('onehot',  OneHotEncoder(handle_unknown='ignore', sparse_output=False)),
        ])
        transformers.append(('cat', cat_transformer, cat_cols))
    if not transformers:
        raise ValueError('No numeric or categorical columns found.')
    return ColumnTransformer(transformers=transformers, remainder='drop')


def _align_test(test_df: pl.DataFrame, feature_cols: list, X_train: pl.DataFrame) -> pl.DataFrame:
    """Align test DataFrame columns to match training feature columns."""
    aligned = pl.DataFrame()
    for col in feature_cols:
        if col in test_df.columns:
            aligned = aligned.with_columns(test_df[col])
        else:
            null_s = pl.Series([None] * test_df.shape[0], dtype=X_train[col].dtype).alias(col)
            aligned = aligned.with_columns(null_s)
    return aligned.select(feature_cols)


def _get_feature_names(preprocessor: ColumnTransformer, numeric_cols: list, cat_cols: list) -> list:
    onehot_cols = []
    if cat_cols:
        enc = preprocessor.named_transformers_['cat'].named_steps['onehot']
        onehot_cols = enc.get_feature_names_out(cat_cols).tolist()
    return numeric_cols + onehot_cols


print('Pipeline helpers defined: build_preprocessor(), _align_test(), _get_feature_names()')
# Out:
# Pipeline helpers defined: build_preprocessor(), _align_test(), _get_feature_names()

# %%
def build_regression_pipeline(
    train_df: pl.DataFrame,
    test_df:  pl.DataFrame,
    target:   str,
    model,
    model_name:   str  = 'Model',
    drop_cols:    list = None,
    n_splits:     int  = 5,
    n_repeats:    int  = 3,
    random_state: int  = 42,
) -> dict:
    """Same as 3.1 — used for LinearRegression baseline only (no HPO)."""
    all_drop     = [c for c in ([target] + (drop_cols or [])) if c in train_df.columns]
    feature_cols = [c for c in train_df.columns if c not in all_drop]
    X_train = train_df.select(feature_cols)
    y_train = train_df[target].to_numpy()
    X_test  = _align_test(test_df, feature_cols, X_train)
    y_test  = test_df[target].to_numpy()

    numeric_cols = [c for c in X_train.columns if X_train[c].dtype in _NUMERIC_DTYPES]
    cat_cols     = [c for c in X_train.columns if X_train[c].dtype in _STRING_DTYPES]
    print(f'  Features : {len(numeric_cols)} numeric, {len(cat_cols)} categorical')

    preprocessor = build_preprocessor(numeric_cols, cat_cols)
    cv = RepeatedKFold(n_splits=n_splits, n_repeats=n_repeats, random_state=random_state)
    scoring = { 'MAE': 'neg_mean_absolute_error', 'RMSE': 'neg_root_mean_squared_error', 'R2': 'r2' }
    pipe = Pipeline([('pre', preprocessor), ('model', model)])

    cv_res  = cross_validate(pipe, X_train.to_pandas(), y_train, cv=cv, scoring=scoring, n_jobs=-1)
    cv_mae  = float(-cv_res['test_MAE'].mean())
    cv_rmse = float(-cv_res['test_RMSE'].mean())
    cv_r2   = float(cv_res['test_R2'].mean())
    print(f'  CV  : MAE={cv_mae:.4f}  RMSE={cv_rmse:.4f}  R²={cv_r2:.4f}')

    pipeline_final = Pipeline([('pre', build_preprocessor(numeric_cols, cat_cols)), ('model', model)])
    pipeline_final.fit(X_train.to_pandas(), y_train)
    y_pred    = pipeline_final.predict(X_test.to_pandas())
    test_mae  = float(mean_absolute_error(y_test, y_pred))
    test_rmse = float(np.sqrt(mean_squared_error(y_test, y_pred)))
    test_r2   = float(r2_score(y_test, y_pred))
    print(f'  Test: MAE={test_mae:.4f}  RMSE={test_rmse:.4f}  R²={test_r2:.4f}')

    feature_names = _get_feature_names(pipeline_final.named_steps['pre'], numeric_cols, cat_cols)
    return {
        'model_name': model_name, 'pipeline': pipeline_final, 'best_params': {},
        'X_train': X_train, 'X_test': X_test,
        'y_train': y_train, 'y_test': y_test, 'y_pred': y_pred,
        'feature_names': feature_names, 'numeric_cols': numeric_cols, 'cat_cols': cat_cols,
        'cv_mae': cv_mae, 'cv_rmse': cv_rmse, 'cv_r2': cv_r2,
        'test_mae': test_mae, 'test_rmse': test_rmse, 'test_r2': test_r2,
    }

print('build_regression_pipeline() defined.')
# Out:
# build_regression_pipeline() defined.

# %% [markdown]
# ## 3. Load All Datasets
#
# Datasets: **2.1-Manual**, **2.2-UMAP-MICE**, and **2.4-FeatEng** (run notebook 2.4 first).

# %%
DATASETS = {
    '2.1-Manual': {
        'train_path': './data/interim/2.1-train.parquet',
        'test_path':  './data/interim/2.1-test.parquet',
    }
    #,
    # '2.2-UMAP-MICE': {
    #     'train_path': './data/interim/2.2-train.parquet',
    #     'test_path':  './data/interim/2.2-test.parquet',
    # },
    # '2.4-FeatEng': {
    #     # Year column present → enables GroupKFold CV + recency weighting in tune_and_run()
    #     'train_path': './data/interim/2.4-train.parquet',
    #     'test_path':  './data/interim/2.4-test.parquet',
    # }
    # ,
    # 'Pipeline1': {
    #     'train_path': './prepared_datasets/pipeline1_train.parquet',
    #     'test_path':  './prepared_datasets/pipeline1_test.parquet',
    # },
    # 'Pipeline2-MedianMode': {
    #     'train_path': './prepared_datasets/pipeline2_median_mode_train.parquet',
    #     'test_path':  './prepared_datasets/pipeline2_median_mode_test.parquet',
    # },
    # 'Pipeline3-MICE': {
    #     'train_path': './prepared_datasets/pipeline3_mice_train.parquet',
    #     'test_path':  './prepared_datasets/pipeline3_mice_test.parquet',
    # },
}

TARGET   = 'health_gain'
all_data = {}

for label, paths in DATASETS.items():
    train_path = Path(paths['train_path'])
    test_path  = Path(paths['test_path'])
    if not train_path.exists():
        print(f'SKIP {label} — {train_path} not found. Run the corresponding data prep notebook first.')
        continue
    train_pl  = pl.read_parquet(train_path)
    test_pl   = pl.read_parquet(test_path)
    drop_cols = ['OHS_Success'] if 'OHS_Success' in train_pl.columns else []
    has_year  = 'Year' in train_pl.columns
    all_data[label] = (train_pl, test_pl, drop_cols)
    print(f'{label:22s}  train={train_pl.shape}  test={test_pl.shape}  has_Year={has_year}  drop={drop_cols}')

print(f'\nTarget  : {TARGET}')
print(f'Loaded  : {list(all_data.keys())}')
print(f'\nNote: Datasets with Year column will use GroupKFold CV + recency weighting (Year1=0.7, rest=1.0).')

# ── Cache for 3.3 results ─────────────────────────────────────────────────────
RESULTS_PATH_33 = Path('./models/3.3-all_results_cache.joblib')
RESULTS_PATH_33.parent.mkdir(parents=True, exist_ok=True)

if RESULTS_PATH_33.exists():
    all_results_33 = joblib.load(RESULTS_PATH_33)
    print(f'\nLoaded existing 3.3 cache ({sum(len(v) for v in all_results_33.values())} runs)')
    for ds, md in all_results_33.items():
        for m, r in md.items():
            print(f'  ✓  {ds:22s} × {m:<20s}  Test RMSE={r["test_rmse"]:.4f}  R²={r["test_r2"]:.4f}')
else:
    all_results_33 = {}
    print(f'\nNo 3.3 cache found — starting fresh.')
# Out:
# 2.1-Manual              train=(68169, 50)  test=(33365, 50)  has_Year=True  drop=[]
#
# Target  : health_gain
# Loaded  : ['2.1-Manual']
#
# Note: Datasets with Year column will use GroupKFold CV + recency weighting (Year1=0.7, rest=1.0).
#
# Loaded existing 3.3 cache (1 runs)
#   ✓  2.1-Manual             × Ridge                 Test RMSE=7.5466  R²=0.4319

# %% [markdown]
# ## 4. Bayesian HPO — Search Spaces & `tune_and_run()`
#
# Each model type has a dedicated Optuna **search space**. The objective function:
# 1. Pre-processes the training data **once** (fit preprocessor → transform)
# 2. Runs `n_trials` Optuna trials, each evaluating `KFold(5)` CV RMSE on the preprocessed arrays
# 3. Fits the best estimator on the **full** training set via a complete `Pipeline` (for downstream SHAP/saving)
# 4. Runs `RepeatedKFold(5×3)` on the best pipeline to give a stable CV RMSE for the comparison table
# 5. Reports the CV vs Test RMSE **gap** as an overfitting diagnostic

# %%
# ── Search spaces ─────────────────────────────────────────────────────────────
SEARCH_SPACES = {
    'Ridge': lambda trial: {
        'alpha': trial.suggest_float('alpha', 1e-3, 100.0, log=True),
    },
    'Lasso': lambda trial: {
        'alpha':    trial.suggest_float('alpha', 1e-4, 10.0, log=True),
        'max_iter': 20_000,
    },
    'RandomForest': lambda trial: {
        'n_estimators':    trial.suggest_int('n_estimators', 100, 500, step=50),
        'max_depth':       trial.suggest_int('max_depth', 3, 25),
        'min_samples_leaf':trial.suggest_int('min_samples_leaf', 1, 20),
        'max_features':    trial.suggest_categorical('max_features', ['sqrt', 'log2', 0.5, 0.8]),
        'n_jobs': -1, 'random_state': 42,
    },
    'HistGBM': lambda trial: {
        'max_iter':          trial.suggest_int('max_iter', 100, 700, step=50),
        'max_depth':         trial.suggest_int('max_depth', 3, 12),
        'learning_rate':     trial.suggest_float('learning_rate', 0.005, 0.3, log=True),
        'l2_regularization': trial.suggest_float('l2_regularization', 1e-6, 10.0, log=True),
        'min_samples_leaf':  trial.suggest_int('min_samples_leaf', 5, 80),
        'random_state': 42,
    },
    # MLP — Multi-layer Perceptron (sklearn).
    # Architecture: 1–3 hidden layers; tuned via categorical choices to keep the
    # Optuna search space discrete and avoid variable-length parameter issues.
    # StandardScaler (already in the pipeline) is essential for MLP convergence.
    # early_stopping=True halts training when validation score stops improving,
    # preventing epoch-level overfitting without manual max_iter tuning.
    'MLP': lambda trial: {
        'hidden_layer_sizes': trial.suggest_categorical(
            'hidden_layer_sizes',
            [(64,), (128,), (256,), (64, 32), (128, 64), (256, 128), (128, 64, 32)],
        ),
        'activation':         trial.suggest_categorical('activation', ['relu', 'tanh']),
        'alpha':              trial.suggest_float('alpha', 1e-5, 1e-1, log=True),
        'learning_rate_init': trial.suggest_float('learning_rate_init', 1e-4, 1e-2, log=True),
        'solver':             'adam',
        'max_iter':           500,
        'early_stopping':     True,
        'validation_fraction': 0.1,
        'n_iter_no_change':   20,
        'random_state':       42,
    },
}

if _xgb_available:
    SEARCH_SPACES['XGBoost'] = lambda trial: {
        'n_estimators':    trial.suggest_int('n_estimators', 100, 800, step=50),
        'learning_rate':   trial.suggest_float('learning_rate', 0.005, 0.3, log=True),
        'max_depth':       trial.suggest_int('max_depth', 3, 10),
        'subsample':       trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree':trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight':trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha':       trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda':      trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        'random_state': 42, 'n_jobs': -1, 'verbosity': 0,
    }

if _catboost_available:
    # CatBoost uses ordered boosting — inherently resistant to overfitting on temporal splits.
    SEARCH_SPACES['CatBoost'] = lambda trial: {
        'iterations':       trial.suggest_int('iterations', 100, 700, step=50),
        'depth':            trial.suggest_int('depth', 3, 10),
        'learning_rate':    trial.suggest_float('learning_rate', 0.005, 0.3, log=True),
        'l2_leaf_reg':      trial.suggest_float('l2_leaf_reg', 1e-3, 10.0, log=True),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 5, 80),
        'random_seed': 42, 'verbose': 0, 'thread_count': -1,
    }

if _ebm_available:
    # EBM (Explainable Boosting Machine) — GA2M: interpretable as a sum of shape functions
    # + optional pairwise interactions. Native feature importance plots (no SHAP proxy needed).
    # Tuned parameters: max_rounds (boosting rounds), learning_rate, max_bins (histogram bins),
    # interactions (number of GA2M pairwise terms), min_samples_leaf.
    SEARCH_SPACES['EBM'] = lambda trial: {
        'max_rounds':       trial.suggest_int('max_rounds', 1000, 8000, step=500),
        'learning_rate':    trial.suggest_float('learning_rate', 0.005, 0.05, log=True),
        'max_bins':         trial.suggest_categorical('max_bins', [128, 256, 512]),
        'interactions':     trial.suggest_int('interactions', 0, 15),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 2, 20),
        'random_state': 42,
    }

MODEL_CLASSES = {
    'Ridge':        Ridge,
    'Lasso':        Lasso,
    'RandomForest': RandomForestRegressor,
    'HistGBM':      HistGradientBoostingRegressor,
    'MLP':          MLPRegressor,
}
if _xgb_available:
    MODEL_CLASSES['XGBoost'] = XGBRegressor
if _catboost_available:
    MODEL_CLASSES['CatBoost'] = CatBoostRegressor
if _ebm_available:
    MODEL_CLASSES['EBM'] = ExplainableBoostingRegressor

print(f'Search spaces defined for: {list(SEARCH_SPACES.keys())}')
# Out:
# Search spaces defined for: ['Ridge', 'Lasso', 'RandomForest', 'HistGBM', 'MLP', 'XGBoost', 'CatBoost', 'EBM']

# %%
def tune_and_run(
    dataset_label: str,
    model_name:    str,
    n_trials:      int = 40,
) -> dict:
    """
    Bayesian HPO (Optuna) + final evaluation for one (dataset × model) pair.

    Design:
    - Preprocessor is fitted ONCE on training data; Optuna trials run on pre-transformed arrays
      → fast trials (~50 ms each for linear models, ~500 ms for trees).
    - After best params found, a full Pipeline([pre, model]) is built for SHAP / downstream use.
    - CV vs Test RMSE gap is printed as overfitting diagnostic.

    Temporal enhancements (applied automatically when 'Year' column is present):
    - GroupKFold CV by Year in Optuna objective → temporally honest hyperparameter search.
    - Recency weighting: oldest year = 0.7, all newer years = 1.0 → model upweights recent data.
    """
    if model_name not in SEARCH_SPACES:
        raise ValueError(f"No search space for '{model_name}'. Available: {list(SEARCH_SPACES.keys())}")
    if dataset_label not in all_data:
        raise KeyError(f"Dataset '{dataset_label}' not loaded. Check all_data keys: {list(all_data.keys())}")

    print(f'\n▶  Tuning {dataset_label}  ×  {model_name}  ({n_trials} Optuna trials)')

    train_pl, test_pl, drop_cols = all_data[dataset_label]

    # ── 0. Drop rows where the target is missing ───────────────────────────────
    n_before = len(train_pl)
    train_pl = train_pl.drop_nulls(subset=[TARGET])
    n_dropped = n_before - len(train_pl)
    if n_dropped:
        print(f'  Dropped {n_dropped} train rows with null target.')

    n_before = len(test_pl)
    test_pl = test_pl.drop_nulls(subset=[TARGET])
    n_dropped = n_before - len(test_pl)
    if n_dropped:
        print(f'  Dropped {n_dropped} test rows with null target.')

    # ── 1. Feature / target separation ────────────────────────────────────────
    all_drop     = [c for c in ([TARGET] + drop_cols) if c in train_pl.columns]
    feature_cols = [c for c in train_pl.columns if c not in all_drop]
    X_train_pl   = train_pl.select(feature_cols)
    y_train      = train_pl[TARGET].to_numpy()
    X_test_pl    = _align_test(test_pl, feature_cols, X_train_pl)
    y_test       = test_pl[TARGET].to_numpy()

    numeric_cols = [c for c in X_train_pl.columns if X_train_pl[c].dtype in _NUMERIC_DTYPES]
    cat_cols     = [c for c in X_train_pl.columns if X_train_pl[c].dtype in _STRING_DTYPES]
    print(f'  Features: {len(numeric_cols)} numeric, {len(cat_cols)} categorical')

    # ── 2. Fit preprocessor ONCE on full training set ─────────────────────────
    pre_for_tuning = build_preprocessor(numeric_cols, cat_cols)
    X_train_prep   = pre_for_tuning.fit_transform(X_train_pl.to_pandas())
    X_test_prep    = pre_for_tuning.transform(X_test_pl.to_pandas())

    # ── 2b. Temporal CV setup + recency weighting (Year column required) ───────
    sample_weight = None   # used in final pipeline fit
    year_groups   = None   # used in Optuna GroupKFold CV
    cv_for_optuna = KFold(n_splits=5, shuffle=True, random_state=42)
    cv_note       = 'KFold(5, shuffled)'

    if 'Year' in train_pl.columns:
        year_arr     = train_pl['Year'].to_numpy()
        unique_years = np.unique(year_arr)
        min_year     = unique_years.min()

        # Recency weights: oldest year ← 0.7, all others ← 1.0
        # Upweights recent years so the model better approximates Year 3 distribution
        sample_weight = np.where(year_arr == min_year, 0.7, 1.0)

        # GroupKFold by Year: each fold validates a full year, never mixing years
        # This is more honest than random KFold when test set is a future year
        n_folds       = max(2, len(unique_years))
        cv_for_optuna = GroupKFold(n_splits=n_folds)
        year_groups   = year_arr

        cv_note = f'GroupKFold({n_folds} year groups)'
        print(f'  Year CV   : {cv_note}  |  recency weight: Year {int(min_year)}=0.7, rest=1.0')
    else:
        print(f'  Year CV   : {cv_note}  (no Year column — temporal enhancements skipped)')

    # ── 3. Optuna objective (uses pre-transformed arrays for speed) ────────────
    import time
    _trial_times = []

    def objective(trial):
        t0     = time.time()
        params = SEARCH_SPACES[model_name](trial)
        mdl    = MODEL_CLASSES[model_name](**params)

        if sample_weight is not None:
            # sklearn >= 1.6: use 'params' instead of the removed 'fit_params'
            # sklearn < 1.4:  use 'fit_params' — detected at runtime via hasattr
            import sklearn
            sk_version = tuple(int(x) for x in sklearn.__version__.split('.')[:2])
            if sk_version >= (1, 6):
                scores = cross_val_score(
                    mdl, X_train_prep, y_train,
                    cv=cv_for_optuna,
                    groups=year_groups,
                    scoring='neg_root_mean_squared_error',
                    n_jobs=-1,
                    params={'sample_weight': sample_weight},
                )
            else:
                scores = cross_val_score(
                    mdl, X_train_prep, y_train,
                    cv=cv_for_optuna,
                    groups=year_groups,
                    scoring='neg_root_mean_squared_error',
                    n_jobs=-1,
                    fit_params={'sample_weight': sample_weight},
                )
        else:
            scores = cross_val_score(
                mdl, X_train_prep, y_train,
                cv=cv_for_optuna,
                groups=year_groups,
                scoring='neg_root_mean_squared_error',
                n_jobs=-1,
            )

        elapsed = time.time() - t0
        _trial_times.append(elapsed)
        completed  = len(_trial_times)
        remaining  = n_trials - completed
        avg_time   = sum(_trial_times) / completed
        eta_sec    = avg_time * remaining
        eta_str    = f'{eta_sec/60:.1f} min' if eta_sec >= 60 else f'{eta_sec:.0f} s'
        rmse       = float(-scores.mean())
        print(f'  Trial {completed:>3}/{n_trials}  RMSE={rmse:.4f}  '
              f'trial_time={elapsed:.1f}s  ETA={eta_str}', end='\r')
        return rmse

    study = optuna.create_study(
        direction='minimize',
        sampler=optuna.samplers.TPESampler(seed=42),
        pruner=optuna.pruners.MedianPruner(n_startup_trials=5),
    )
    study.optimize(objective, n_trials=n_trials, show_progress_bar=False)
    print()  # newline after \r progress

    best_params       = study.best_params
    optuna_best_rmse  = study.best_value
    print(f'  Optuna best CV RMSE     : {optuna_best_rmse:.4f}  (via {cv_note})')
    print(f'  Best params             : {best_params}')

    # ── 4. Build final Pipeline with best params (for SHAP + downstream use) ──
    best_model     = MODEL_CLASSES[model_name](**best_params)
    pre_final      = build_preprocessor(numeric_cols, cat_cols)
    pipeline_final = Pipeline([('pre', pre_final), ('model', best_model)])

    # Apply recency weighting in final fit when Year is available
    if sample_weight is not None:
        pipeline_final.fit(X_train_pl.to_pandas(), y_train,
                           model__sample_weight=sample_weight)
    else:
        pipeline_final.fit(X_train_pl.to_pandas(), y_train)

    # ── 5. Test-set metrics ────────────────────────────────────────────────────
    y_pred    = pipeline_final.predict(X_test_pl.to_pandas())
    test_mae  = float(mean_absolute_error(y_test, y_pred))
    test_rmse = float(np.sqrt(mean_squared_error(y_test, y_pred)))
    test_r2   = float(r2_score(y_test, y_pred))

    # ── 6. Stable CV on best pipeline (RepeatedKFold) for comparison table ────
    cv_scoring = { 'MAE': 'neg_mean_absolute_error', 'RMSE': 'neg_root_mean_squared_error', 'R2': 'r2' }
    cv_pipe_for_eval = Pipeline([('pre', build_preprocessor(numeric_cols, cat_cols)),
                                  ('model', MODEL_CLASSES[model_name](**best_params))])
    cv_res = cross_validate(
        cv_pipe_for_eval, X_train_pl.to_pandas(), y_train,
        cv=RepeatedKFold(n_splits=5, n_repeats=3, random_state=42),
        scoring=cv_scoring, n_jobs=-1,
    )
    cv_rmse = float(-cv_res['test_RMSE'].mean())
    cv_r2   = float(cv_res['test_R2'].mean())
    cv_mae  = float(-cv_res['test_MAE'].mean())

    gap = test_rmse - cv_rmse
    gap_flag = ' ⚠ possible overfit' if gap > 0.5 else ''
    print(f'  CV RMSE  : {cv_rmse:.4f}  |  Test RMSE: {test_rmse:.4f}  |  Gap: {gap:+.4f}{gap_flag}')
    print(f'  Test R²  : {test_r2:.4f}')

    # ── 7. Feature names ───────────────────────────────────────────────────────
    feature_names = _get_feature_names(pipeline_final.named_steps['pre'], numeric_cols, cat_cols)

    result = {
        'model_name':          model_name,
        'best_params':         best_params,
        'optuna_best_cv_rmse': optuna_best_rmse,
        'pipeline':            pipeline_final,
        'X_train':             X_train_pl,
        'X_test':              X_test_pl,
        'y_train':             y_train,
        'y_test':              y_test,
        'y_pred':              y_pred,
        'feature_names':       feature_names,
        'numeric_cols':        numeric_cols,
        'cat_cols':            cat_cols,
        'cv_mae':  cv_mae,  'cv_rmse':  cv_rmse,  'cv_r2':  cv_r2,
        'test_mae': test_mae, 'test_rmse': test_rmse, 'test_r2': test_r2,
    }

    all_results_33.setdefault(dataset_label, {})[model_name] = result
    joblib.dump(all_results_33, RESULTS_PATH_33)
    print(f'  ✓ Saved → {RESULTS_PATH_33}')
    return result


print('tune_and_run() defined.')
print('  Temporal enhancements: GroupKFold CV + recency weighting (auto-enabled when Year column present).')
# Out:
# tune_and_run() defined.
#   Temporal enhancements: GroupKFold CV + recency weighting (auto-enabled when Year column present).

# %%
for ds in all_data:
    tune_and_run(ds, 'Ridge', n_trials=40)
# Out:
# ▶  Tuning 2.1-Manual  ×  Ridge  (40 Optuna trials)
#   Dropped 3728 train rows with null target.
#   Dropped 1820 test rows with null target.
#   Features: 48 numeric, 0 categorical
#   Year CV   : GroupKFold(2 year groups)  |  recency weight: Year 1=0.7, rest=1.0
#   Trial  40/40  RMSE=7.6788  trial_time=0.2s  ETA=0 ssmin
#   Optuna best CV RMSE     : 7.6788  (via GroupKFold(2 year groups))
#   Best params             : {'alpha': 93.78749989193129}
#   CV RMSE  : 7.6619  |  Test RMSE: 7.5466  |  Gap: -0.1153
#   Test R²  : 0.4319
#   ✓ Saved → models\3.3-all_results_cache.joblib

# %% [markdown]
# ### Lasso (tuned `alpha` over [0.0001, 10] — enables true feature selection)

# %%
for ds in all_data:
    tune_and_run(ds, 'Lasso', n_trials=40)
# Out:
# ▶  Tuning 2.1-Manual  ×  Lasso  (40 Optuna trials)
#   Dropped 3728 train rows with null target.
#   Dropped 1820 test rows with null target.
#   Features: 48 numeric, 0 categorical
#   Year CV   : GroupKFold(2 year groups)  |  recency weight: Year 1=0.7, rest=1.0
#   Trial  40/40  RMSE=7.6792  trial_time=0.6s  ETA=0 sssinn
#   Optuna best CV RMSE     : 7.6787  (via GroupKFold(2 year groups))
#   Best params             : {'alpha': 0.002692579279003267}
#   CV RMSE  : 7.6619  |  Test RMSE: 7.5464  |  Gap: -0.1155
#   Test R²  : 0.4319
#   ✓ Saved → models\3.3-all_results_cache.joblib

# %% [markdown]
# ### Random Forest (tuned `n_estimators`, `max_depth`, `min_samples_leaf`, `max_features`)

# %%
for ds in all_data:
    tune_and_run(ds, 'RandomForest', n_trials=40)
# Out:
# ▶  Tuning 2.1-Manual  ×  RandomForest  (40 Optuna trials)
#   Dropped 3728 train rows with null target.
#   Dropped 1820 test rows with null target.
#   Features: 48 numeric, 0 categorical
#   Year CV   : GroupKFold(2 year groups)  |  recency weight: Year 1=0.7, rest=1.0
#   Trial  40/40  RMSE=7.6943  trial_time=4.8s  ETA=0 sssmin
#   Optuna best CV RMSE     : 7.6925  (via GroupKFold(2 year groups))
#   Best params             : {'n_estimators': 500, 'max_depth': 23, 'min_samples_leaf': 2, 'max_features': 'sqrt'}
#   CV RMSE  : 7.6624  |  Test RMSE: 7.5568  |  Gap: -0.1057
#   Test R²  : 0.4303
#   ✓ Saved → models\3.3-all_results_cache.joblib

# %% [markdown]
# ### HistGradientBoosting (tuned `max_iter`, `max_depth`, `learning_rate`, `l2`, `min_samples_leaf`)

# %%
for ds in all_data:
    tune_and_run(ds, 'HistGBM', n_trials=40)
# Out:
# ▶  Tuning 2.1-Manual  ×  HistGBM  (40 Optuna trials)
#   Dropped 3728 train rows with null target.
#   Dropped 1820 test rows with null target.
#   Features: 48 numeric, 0 categorical
#   Year CV   : GroupKFold(2 year groups)  |  recency weight: Year 1=0.7, rest=1.0
#   Trial  40/40  RMSE=7.6294  trial_time=4.3s  ETA=0 ssminn
#   Optuna best CV RMSE     : 7.6133  (via GroupKFold(2 year groups))
#   Best params             : {'max_iter': 400, 'max_depth': 3, 'learning_rate': 0.05016465850518881, 'l2_regularization': 0.02718528937569743, 'min_samples_leaf': 49}
#   CV RMSE  : 7.5880  |  Test RMSE: 7.4889  |  Gap: -0.0991
#   Test R²  : 0.4405
#   ✓ Saved → models\3.3-all_results_cache.joblib

# %% [markdown]
# ### XGBoost (tuned `n_estimators`, `learning_rate`, `max_depth`, `subsample`, `colsample_bytree`, `reg_alpha/lambda`)

# %%
if _xgb_available:
    for ds in all_data:
        tune_and_run(ds, 'XGBoost', n_trials=40)
else:
    print('XGBoost not available — skipping.')
# Out:
# ▶  Tuning 2.1-Manual  ×  XGBoost  (40 Optuna trials)
#   Dropped 3728 train rows with null target.
#   Dropped 1820 test rows with null target.
#   Features: 48 numeric, 0 categorical
#   Year CV   : GroupKFold(2 year groups)  |  recency weight: Year 1=0.7, rest=1.0
#   Trial  40/40  RMSE=7.6368  trial_time=1.9s  ETA=0 ssmin
#   Optuna best CV RMSE     : 7.6096  (via GroupKFold(2 year groups))
#   Best params             : {'n_estimators': 800, 'learning_rate': 0.018305897515281857, 'max_depth': 4, 'subsample': 0.8191336187389799, 'colsample_bytree': 0.7070320328200373, 'min_child_weight': 7, 'reg_alpha': 9.840588632342705, 'reg_lambda': 0.00107081155162849}
#   CV RMSE  : 7.5752  |  Test RMSE: 7.4812  |  Gap: -0.0940
#   Test R²  : 0.4417
#   ✓ Saved → models\3.3-all_results_cache.joblib

# %% [markdown]
# ### CatBoost (ordered boosting — best-suited for temporal holdout splits)
#
# CatBoost uses **ordered boosting**: each tree is built so that no training residual for row _i_ uses
# row _i_ itself — equivalent to out-of-fold estimation at every step. This directly mirrors what
# a temporal holdout expects: the model must not "see" the future year while learning from the past.
#
# Tuned parameters: `iterations` (≡ n_estimators), `depth`, `learning_rate`, `l2_leaf_reg`, `min_data_in_leaf`.
# For datasets with a `Year` column (e.g. **2.4-FeatEng**), GroupKFold CV and recency weighting are applied automatically.

# %%
if _catboost_available:
    for ds in all_data:
        tune_and_run(ds, 'CatBoost', n_trials=40)
else:
    print('CatBoost not available — run pip install catboost and restart the kernel.')
# Out:
# ▶  Tuning 2.1-Manual  ×  CatBoost  (40 Optuna trials)
#   Dropped 3728 train rows with null target.
#   Dropped 1820 test rows with null target.
#   Features: 48 numeric, 0 categorical
#   Year CV   : GroupKFold(2 year groups)  |  recency weight: Year 1=0.7, rest=1.0
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 1 fits failed out of a total of 2.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\catboost\core.py", line 6178, in fit
#     return self._fit(X, y, cat_features, text_features, embedding_features, None, graph, sample_weight, None, None, None, None, baseline,
#   File "c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\catboost\core.py", line 2716, in _fit
#     self._train(
#   File "c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\catboost\core.py", line 1824, in _train
#     self._object._train(train_pool, test_pool, params, allow_clear_pool, init_model._object if init_model else None)
#   File "_catboost.pyx", line 5430, in _catboost._CatBoost._train
#   File "_catboost.pyx", line 5479, in _catboost._CatBoost._train
# _catboost.CatBoostError: catboost/libs/train_lib/dir_helper.cpp:20: Can't create train working dir: catboost_info
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# [W 2026-05-01 16:49:18,721] Trial 0 failed with parameters: {'iterations': 300, 'depth': 10, 'learning_rate': 0.1001303991139125, 'l2_leaf_reg': 0.24810409748678125, 'min_data_in_leaf': 16} because of the following error: The value nan is not acceptable.
# [W 2026-05-01 16:49:18,725] Trial 0 failed with value nan.
#   Trial  40/40  RMSE=7.6264  trial_time=10.2s  ETA=0 sminn
#   Optuna best CV RMSE     : 7.5953  (via GroupKFold(2 year groups))
#   Best params             : {'iterations': 650, 'depth': 7, 'learning_rate': 0.021733486805300007, 'l2_leaf_reg': 2.535437259179828, 'min_data_in_leaf': 43}
# 0:	learn: 9.9821072	total: 148ms	remaining: 1m 36s
# 1:	learn: 9.9118457	total: 156ms	remaining: 50.4s
# 2:	learn: 9.8440107	total: 163ms	remaining: 35.1s
# 3:	learn: 9.7787918	total: 170ms	remaining: 27.5s
# 4:	learn: 9.7161949	total: 177ms	remaining: 22.8s
# 5:	learn: 9.6563287	total: 183ms	remaining: 19.7s
# 6:	learn: 9.5980656	total: 190ms	remaining: 17.5s
# 7:	learn: 9.5409954	total: 197ms	remaining: 15.8s
# 8:	learn: 9.4877316	total: 205ms	remaining: 14.6s
# 9:	learn: 9.4360067	total: 212ms	remaining: 13.6s
# 10:	learn: 9.3852944	total: 219ms	remaining: 12.7s
# 11:	learn: 9.3359388	total: 227ms	remaining: 12.1s
# 12:	learn: 9.2879444	total: 235ms	remaining: 11.5s
# 13:	learn: 9.2413477	total: 242ms	remaining: 11s
# 14:	learn: 9.1970820	total: 250ms	remaining: 10.6s
# 15:	learn: 9.1535668	total: 257ms	remaining: 10.2s
# 16:	learn: 9.1115890	total: 265ms	remaining: 9.87s
# 17:	learn: 9.0718912	total: 273ms	remaining: 9.57s
# 18:	learn: 9.0325765	total: 280ms	remaining: 9.3s
# 19:	learn: 8.9959772	total: 288ms	remaining: 9.06s
# 20:	learn: 8.9594422	total: 296ms	remaining: 8.86s
# 21:	learn: 8.9235773	total: 303ms	remaining: 8.66s
# 22:	learn: 8.8893748	total: 312ms	remaining: 8.5s
# 23:	learn: 8.8551048	total: 319ms	remaining: 8.33s
# 24:	learn: 8.8228503	total: 328ms	remaining: 8.19s
# 25:	learn: 8.7906430	total: 335ms	remaining: 8.04s
# 26:	learn: 8.7605016	total: 345ms	remaining: 7.95s
# 27:	learn: 8.7307678	total: 353ms	remaining: 7.84s
# 28:	learn: 8.7029777	total: 362ms	remaining: 7.75s
# 29:	learn: 8.6734197	total: 371ms	remaining: 7.66s
# 30:	learn: 8.6463786	total: 378ms	remaining: 7.55s
# 31:	learn: 8.6197848	total: 388ms	remaining: 7.49s
# 32:	learn: 8.5937215	total: 397ms	remaining: 7.43s
# 33:	learn: 8.5690807	total: 406ms	remaining: 7.36s
# 34:	learn: 8.5444628	total: 417ms	remaining: 7.33s
# 35:	learn: 8.5212071	total: 426ms	remaining: 7.26s
# 36:	learn: 8.4984379	total: 434ms	remaining: 7.19s
# 37:	learn: 8.4760409	total: 443ms	remaining: 7.13s
# 38:	learn: 8.4533658	total: 451ms	remaining: 7.06s
# 39:	learn: 8.4328959	total: 459ms	remaining: 6.99s
# 40:	learn: 8.4120614	total: 466ms	remaining: 6.93s
# 41:	learn: 8.3917548	total: 476ms	remaining: 6.89s
# 42:	learn: 8.3722243	total: 486ms	remaining: 6.86s
# 43:	learn: 8.3538997	total: 494ms	remaining: 6.8s
# 44:	learn: 8.3362570	total: 503ms	remaining: 6.76s
# 45:	learn: 8.3182169	total: 511ms	remaining: 6.71s
# 46:	learn: 8.3002220	total: 520ms	remaining: 6.67s
# 47:	learn: 8.2839245	total: 528ms	remaining: 6.63s
# 48:	learn: 8.2674143	total: 537ms	remaining: 6.58s
# 49:	learn: 8.2514879	total: 545ms	remaining: 6.54s
# 50:	learn: 8.2365985	total: 554ms	remaining: 6.51s
# 51:	learn: 8.2210754	total: 562ms	remaining: 6.46s
# 52:	learn: 8.2067447	total: 571ms	remaining: 6.43s
# 53:	learn: 8.1922707	total: 580ms	remaining: 6.41s
# 54:	learn: 8.1781452	total: 589ms	remaining: 6.37s
# 55:	learn: 8.1643052	total: 598ms	remaining: 6.34s
# 56:	learn: 8.1518153	total: 607ms	remaining: 6.31s
# 57:	learn: 8.1395039	total: 615ms	remaining: 6.28s
# 58:	learn: 8.1268559	total: 623ms	remaining: 6.24s
# 59:	learn: 8.1148674	total: 631ms	remaining: 6.21s
# 60:	learn: 8.1031386	total: 640ms	remaining: 6.17s
# 61:	learn: 8.0914077	total: 648ms	remaining: 6.14s
# 62:	learn: 8.0810154	total: 656ms	remaining: 6.11s
# 63:	learn: 8.0704039	total: 664ms	remaining: 6.08s
# 64:	learn: 8.0605846	total: 673ms	remaining: 6.05s
# 65:	learn: 8.0509271	total: 681ms	remaining: 6.03s
# 66:	learn: 8.0408949	total: 689ms	remaining: 6s
# 67:	learn: 8.0309212	total: 698ms	remaining: 5.97s
# 68:	learn: 8.0217753	total: 706ms	remaining: 5.94s
# 69:	learn: 8.0126158	total: 714ms	remaining: 5.92s
# 70:	learn: 8.0037715	total: 722ms	remaining: 5.89s
# 71:	learn: 7.9944217	total: 730ms	remaining: 5.86s
# 72:	learn: 7.9853656	total: 738ms	remaining: 5.83s
# 73:	learn: 7.9765962	total: 747ms	remaining: 5.81s
# 74:	learn: 7.9682071	total: 755ms	remaining: 5.79s
# 75:	learn: 7.9600085	total: 763ms	remaining: 5.76s
# 76:	learn: 7.9516722	total: 772ms	remaining: 5.74s
# 77:	learn: 7.9439922	total: 780ms	remaining: 5.72s
# 78:	learn: 7.9364426	total: 789ms	remaining: 5.7s
# 79:	learn: 7.9287002	total: 798ms	remaining: 5.68s
# 80:	learn: 7.9212417	total: 807ms	remaining: 5.67s
# 81:	learn: 7.9140181	total: 815ms	remaining: 5.65s
# 82:	learn: 7.9068198	total: 823ms	remaining: 5.62s
# 83:	learn: 7.9004622	total: 831ms	remaining: 5.6s
# 84:	learn: 7.8942330	total: 840ms	remaining: 5.58s
# 85:	learn: 7.8877490	total: 849ms	remaining: 5.57s
# 86:	learn: 7.8812815	total: 857ms	remaining: 5.54s
# 87:	learn: 7.8754420	total: 865ms	remaining: 5.52s
# 88:	learn: 7.8691969	total: 874ms	remaining: 5.51s
# 89:	learn: 7.8638315	total: 882ms	remaining: 5.49s
# 90:	learn: 7.8578327	total: 891ms	remaining: 5.47s
# 91:	learn: 7.8520321	total: 899ms	remaining: 5.45s
# 92:	learn: 7.8463861	total: 907ms	remaining: 5.43s
# 93:	learn: 7.8409780	total: 915ms	remaining: 5.41s
# 94:	learn: 7.8356061	total: 923ms	remaining: 5.39s
# 95:	learn: 7.8304168	total: 931ms	remaining: 5.37s
# 96:	learn: 7.8255484	total: 940ms	remaining: 5.36s
# 97:	learn: 7.8206010	total: 949ms	remaining: 5.34s
# 98:	learn: 7.8158180	total: 957ms	remaining: 5.32s
# 99:	learn: 7.8113440	total: 966ms	remaining: 5.31s
# 100:	learn: 7.8071861	total: 975ms	remaining: 5.3s
# 101:	learn: 7.8026611	total: 983ms	remaining: 5.28s
# 102:	learn: 7.7982438	total: 993ms	remaining: 5.27s
# 103:	learn: 7.7939519	total: 1s	remaining: 5.26s
# 104:	learn: 7.7897365	total: 1.01s	remaining: 5.24s
# 105:	learn: 7.7853652	total: 1.02s	remaining: 5.22s
# 106:	learn: 7.7815218	total: 1.03s	remaining: 5.21s
# 107:	learn: 7.7775496	total: 1.03s	remaining: 5.2s
# 108:	learn: 7.7734236	total: 1.04s	remaining: 5.19s
# 109:	learn: 7.7695188	total: 1.05s	remaining: 5.17s
# 110:	learn: 7.7658596	total: 1.06s	remaining: 5.16s
# 111:	learn: 7.7625103	total: 1.07s	remaining: 5.14s
# 112:	learn: 7.7590921	total: 1.08s	remaining: 5.13s
# 113:	learn: 7.7554330	total: 1.09s	remaining: 5.12s
# 114:	learn: 7.7519785	total: 1.1s	remaining: 5.11s
# 115:	learn: 7.7486987	total: 1.11s	remaining: 5.09s
# 116:	learn: 7.7456134	total: 1.11s	remaining: 5.08s
# 117:	learn: 7.7423799	total: 1.12s	remaining: 5.06s
# 118:	learn: 7.7392921	total: 1.13s	remaining: 5.05s
# 119:	learn: 7.7355381	total: 1.14s	remaining: 5.04s
# 120:	learn: 7.7325317	total: 1.15s	remaining: 5.02s
# 121:	learn: 7.7294861	total: 1.16s	remaining: 5s
# 122:	learn: 7.7264388	total: 1.17s	remaining: 4.99s
# 123:	learn: 7.7231585	total: 1.17s	remaining: 4.98s
# 124:	learn: 7.7198624	total: 1.18s	remaining: 4.97s
# 125:	learn: 7.7172431	total: 1.19s	remaining: 4.96s
# 126:	learn: 7.7141917	total: 1.21s	remaining: 4.97s
# 127:	learn: 7.7115585	total: 1.22s	remaining: 5s
# 128:	learn: 7.7084842	total: 1.24s	remaining: 5s
# 129:	learn: 7.7056489	total: 1.25s	remaining: 5s
# 130:	learn: 7.7029590	total: 1.26s	remaining: 4.99s
# 131:	learn: 7.7003938	total: 1.27s	remaining: 5s
# 132:	learn: 7.6980187	total: 1.28s	remaining: 4.99s
# 133:	learn: 7.6951568	total: 1.29s	remaining: 4.98s
# 134:	learn: 7.6926105	total: 1.3s	remaining: 4.97s
# 135:	learn: 7.6903012	total: 1.31s	remaining: 4.95s
# 136:	learn: 7.6876616	total: 1.32s	remaining: 4.94s
# 137:	learn: 7.6852722	total: 1.33s	remaining: 4.93s
# 138:	learn: 7.6829393	total: 1.34s	remaining: 4.92s
# 139:	learn: 7.6808207	total: 1.34s	remaining: 4.9s
# 140:	learn: 7.6786905	total: 1.35s	remaining: 4.89s
# 141:	learn: 7.6764952	total: 1.36s	remaining: 4.87s
# 142:	learn: 7.6742807	total: 1.37s	remaining: 4.86s
# 143:	learn: 7.6719065	total: 1.38s	remaining: 4.85s
# 144:	learn: 7.6696569	total: 1.39s	remaining: 4.83s
# 145:	learn: 7.6676468	total: 1.4s	remaining: 4.82s
# 146:	learn: 7.6655951	total: 1.41s	remaining: 4.82s
# 147:	learn: 7.6637839	total: 1.42s	remaining: 4.8s
# 148:	learn: 7.6618226	total: 1.43s	remaining: 4.79s
# 149:	learn: 7.6599272	total: 1.43s	remaining: 4.78s
# 150:	learn: 7.6580291	total: 1.44s	remaining: 4.76s
# 151:	learn: 7.6560307	total: 1.45s	remaining: 4.75s
# 152:	learn: 7.6541164	total: 1.46s	remaining: 4.74s
# 153:	learn: 7.6523626	total: 1.47s	remaining: 4.73s
# 154:	learn: 7.6504888	total: 1.48s	remaining: 4.72s
# 155:	learn: 7.6485455	total: 1.49s	remaining: 4.71s
# 156:	learn: 7.6469302	total: 1.5s	remaining: 4.7s
# 157:	learn: 7.6450588	total: 1.5s	remaining: 4.68s
# 158:	learn: 7.6431182	total: 1.51s	remaining: 4.67s
# 159:	learn: 7.6415619	total: 1.52s	remaining: 4.66s
# 160:	learn: 7.6398381	total: 1.53s	remaining: 4.65s
# 161:	learn: 7.6382712	total: 1.54s	remaining: 4.64s
# 162:	learn: 7.6368693	total: 1.55s	remaining: 4.62s
# 163:	learn: 7.6350705	total: 1.55s	remaining: 4.61s
# 164:	learn: 7.6333910	total: 1.56s	remaining: 4.6s
# 165:	learn: 7.6318612	total: 1.57s	remaining: 4.59s
# 166:	learn: 7.6302681	total: 1.58s	remaining: 4.58s
# 167:	learn: 7.6289011	total: 1.59s	remaining: 4.57s
# 168:	learn: 7.6274854	total: 1.6s	remaining: 4.56s
# 169:	learn: 7.6260781	total: 1.61s	remaining: 4.55s
# 170:	learn: 7.6246624	total: 1.62s	remaining: 4.54s
# 171:	learn: 7.6233121	total: 1.63s	remaining: 4.53s
# 172:	learn: 7.6219449	total: 1.64s	remaining: 4.52s
# 173:	learn: 7.6203666	total: 1.65s	remaining: 4.5s
# 174:	learn: 7.6188418	total: 1.65s	remaining: 4.49s
# 175:	learn: 7.6175932	total: 1.66s	remaining: 4.48s
# 176:	learn: 7.6163050	total: 1.67s	remaining: 4.47s
# 177:	learn: 7.6150436	total: 1.68s	remaining: 4.45s
# 178:	learn: 7.6136122	total: 1.69s	remaining: 4.44s
# 179:	learn: 7.6123904	total: 1.7s	remaining: 4.43s
# 180:	learn: 7.6109747	total: 1.71s	remaining: 4.42s
# 181:	learn: 7.6096654	total: 1.71s	remaining: 4.41s
# 182:	learn: 7.6083069	total: 1.72s	remaining: 4.39s
# 183:	learn: 7.6070472	total: 1.73s	remaining: 4.38s
# 184:	learn: 7.6057992	total: 1.74s	remaining: 4.37s
# 185:	learn: 7.6046011	total: 1.75s	remaining: 4.36s
# 186:	learn: 7.6033762	total: 1.75s	remaining: 4.35s
# 187:	learn: 7.6023711	total: 1.76s	remaining: 4.34s
# 188:	learn: 7.6011664	total: 1.77s	remaining: 4.33s
# 189:	learn: 7.5999621	total: 1.78s	remaining: 4.32s
# 190:	learn: 7.5987809	total: 1.79s	remaining: 4.31s
# 191:	learn: 7.5975231	total: 1.8s	remaining: 4.3s
# 192:	learn: 7.5964372	total: 1.81s	remaining: 4.29s
# 193:	learn: 7.5953312	total: 1.82s	remaining: 4.28s
# 194:	learn: 7.5942434	total: 1.83s	remaining: 4.27s
# 195:	learn: 7.5930877	total: 1.84s	remaining: 4.26s
# 196:	learn: 7.5919524	total: 1.85s	remaining: 4.25s
# 197:	learn: 7.5909099	total: 1.86s	remaining: 4.24s
# 198:	learn: 7.5898589	total: 1.87s	remaining: 4.23s
# 199:	learn: 7.5888277	total: 1.88s	remaining: 4.22s
# 200:	learn: 7.5878800	total: 1.89s	remaining: 4.21s
# 201:	learn: 7.5867599	total: 1.89s	remaining: 4.2s
# 202:	learn: 7.5854404	total: 1.9s	remaining: 4.19s
# 203:	learn: 7.5844895	total: 1.91s	remaining: 4.18s
# 204:	learn: 7.5833351	total: 1.92s	remaining: 4.17s
# 205:	learn: 7.5822017	total: 1.93s	remaining: 4.16s
# 206:	learn: 7.5811837	total: 1.94s	remaining: 4.15s
# 207:	learn: 7.5802323	total: 1.95s	remaining: 4.14s
# 208:	learn: 7.5793093	total: 1.96s	remaining: 4.13s
# 209:	learn: 7.5783934	total: 1.97s	remaining: 4.12s
# 210:	learn: 7.5774393	total: 1.98s	remaining: 4.11s
# 211:	learn: 7.5763595	total: 1.99s	remaining: 4.1s
# 212:	learn: 7.5754494	total: 1.99s	remaining: 4.09s
# 213:	learn: 7.5745693	total: 2.02s	remaining: 4.11s
# 214:	learn: 7.5737150	total: 2.03s	remaining: 4.11s
# 215:	learn: 7.5727545	total: 2.04s	remaining: 4.09s
# 216:	learn: 7.5719480	total: 2.05s	remaining: 4.08s
# 217:	learn: 7.5711263	total: 2.06s	remaining: 4.07s
# 218:	learn: 7.5701936	total: 2.06s	remaining: 4.06s
# 219:	learn: 7.5691619	total: 2.07s	remaining: 4.05s
# 220:	learn: 7.5683670	total: 2.08s	remaining: 4.04s
# 221:	learn: 7.5675511	total: 2.09s	remaining: 4.03s
# 222:	learn: 7.5666924	total: 2.1s	remaining: 4.02s
# 223:	learn: 7.5657376	total: 2.11s	remaining: 4.01s
# 224:	learn: 7.5647574	total: 2.12s	remaining: 4s
# 225:	learn: 7.5638366	total: 2.13s	remaining: 3.99s
# 226:	learn: 7.5628100	total: 2.14s	remaining: 3.98s
# 227:	learn: 7.5619741	total: 2.15s	remaining: 3.97s
# 228:	learn: 7.5611005	total: 2.15s	remaining: 3.96s
# 229:	learn: 7.5603088	total: 2.16s	remaining: 3.95s
# 230:	learn: 7.5595851	total: 2.17s	remaining: 3.94s
# 231:	learn: 7.5587958	total: 2.18s	remaining: 3.93s
# 232:	learn: 7.5579916	total: 2.19s	remaining: 3.92s
# 233:	learn: 7.5573067	total: 2.2s	remaining: 3.91s
# 234:	learn: 7.5564614	total: 2.21s	remaining: 3.9s
# 235:	learn: 7.5555741	total: 2.22s	remaining: 3.89s
# 236:	learn: 7.5545079	total: 2.23s	remaining: 3.88s
# 237:	learn: 7.5537096	total: 2.24s	remaining: 3.87s
# 238:	learn: 7.5528730	total: 2.25s	remaining: 3.86s
# 239:	learn: 7.5517968	total: 2.25s	remaining: 3.85s
# 240:	learn: 7.5510498	total: 2.26s	remaining: 3.84s
# 241:	learn: 7.5504379	total: 2.27s	remaining: 3.83s
# 242:	learn: 7.5495488	total: 2.28s	remaining: 3.82s
# 243:	learn: 7.5486973	total: 2.29s	remaining: 3.81s
# 244:	learn: 7.5480079	total: 2.3s	remaining: 3.8s
# 245:	learn: 7.5472033	total: 2.31s	remaining: 3.79s
# 246:	learn: 7.5464987	total: 2.32s	remaining: 3.78s
# 247:	learn: 7.5455582	total: 2.33s	remaining: 3.77s
# 248:	learn: 7.5447889	total: 2.33s	remaining: 3.76s
# 249:	learn: 7.5438828	total: 2.34s	remaining: 3.75s
# 250:	learn: 7.5429449	total: 2.35s	remaining: 3.74s
# 251:	learn: 7.5423044	total: 2.36s	remaining: 3.73s
# 252:	learn: 7.5416819	total: 2.37s	remaining: 3.72s
# 253:	learn: 7.5408184	total: 2.38s	remaining: 3.71s
# 254:	learn: 7.5401922	total: 2.39s	remaining: 3.7s
# 255:	learn: 7.5397494	total: 2.39s	remaining: 3.69s
# 256:	learn: 7.5390611	total: 2.4s	remaining: 3.67s
# 257:	learn: 7.5381804	total: 2.41s	remaining: 3.67s
# 258:	learn: 7.5374657	total: 2.42s	remaining: 3.65s
# 259:	learn: 7.5369125	total: 2.43s	remaining: 3.64s
# 260:	learn: 7.5361558	total: 2.44s	remaining: 3.63s
# 261:	learn: 7.5354251	total: 2.45s	remaining: 3.63s
# 262:	learn: 7.5348331	total: 2.46s	remaining: 3.62s
# 263:	learn: 7.5341943	total: 2.47s	remaining: 3.61s
# 264:	learn: 7.5336300	total: 2.48s	remaining: 3.6s
# 265:	learn: 7.5327725	total: 2.48s	remaining: 3.59s
# 266:	learn: 7.5321167	total: 2.49s	remaining: 3.58s
# 267:	learn: 7.5315190	total: 2.5s	remaining: 3.57s
# 268:	learn: 7.5308708	total: 2.51s	remaining: 3.56s
# 269:	learn: 7.5302079	total: 2.52s	remaining: 3.54s
# 270:	learn: 7.5295550	total: 2.53s	remaining: 3.54s
# 271:	learn: 7.5289156	total: 2.54s	remaining: 3.52s
# 272:	learn: 7.5283514	total: 2.55s	remaining: 3.52s
# 273:	learn: 7.5276333	total: 2.56s	remaining: 3.51s
# 274:	learn: 7.5270075	total: 2.56s	remaining: 3.5s
# 275:	learn: 7.5265842	total: 2.57s	remaining: 3.49s
# 276:	learn: 7.5258840	total: 2.58s	remaining: 3.48s
# 277:	learn: 7.5249468	total: 2.59s	remaining: 3.47s
# 278:	learn: 7.5243208	total: 2.6s	remaining: 3.46s
# 279:	learn: 7.5238552	total: 2.61s	remaining: 3.45s
# 280:	learn: 7.5231767	total: 2.62s	remaining: 3.44s
# 281:	learn: 7.5227210	total: 2.63s	remaining: 3.43s
# 282:	learn: 7.5218005	total: 2.64s	remaining: 3.42s
# 283:	learn: 7.5210538	total: 2.65s	remaining: 3.41s
# 284:	learn: 7.5205332	total: 2.66s	remaining: 3.4s
# 285:	learn: 7.5198812	total: 2.67s	remaining: 3.39s
# 286:	learn: 7.5191192	total: 2.68s	remaining: 3.38s
# 287:	learn: 7.5183758	total: 2.68s	remaining: 3.37s
# 288:	learn: 7.5174506	total: 2.69s	remaining: 3.36s
# 289:	learn: 7.5168332	total: 2.7s	remaining: 3.35s
# 290:	learn: 7.5161741	total: 2.71s	remaining: 3.35s
# 291:	learn: 7.5156096	total: 2.72s	remaining: 3.34s
# 292:	learn: 7.5150592	total: 2.73s	remaining: 3.33s
# 293:	learn: 7.5143682	total: 2.74s	remaining: 3.32s
# 294:	learn: 7.5138648	total: 2.75s	remaining: 3.31s
# 295:	learn: 7.5132996	total: 2.76s	remaining: 3.3s
# 296:	learn: 7.5125072	total: 2.77s	remaining: 3.29s
# 297:	learn: 7.5120846	total: 2.77s	remaining: 3.28s
# 298:	learn: 7.5115341	total: 2.78s	remaining: 3.27s
# 299:	learn: 7.5110376	total: 2.79s	remaining: 3.26s
# 300:	learn: 7.5104191	total: 2.8s	remaining: 3.25s
# 301:	learn: 7.5095812	total: 2.81s	remaining: 3.24s
# 302:	learn: 7.5089591	total: 2.82s	remaining: 3.23s
# 303:	learn: 7.5083618	total: 2.83s	remaining: 3.22s
# 304:	learn: 7.5076310	total: 2.84s	remaining: 3.21s
# 305:	learn: 7.5071583	total: 2.85s	remaining: 3.2s
# 306:	learn: 7.5066021	total: 2.86s	remaining: 3.19s
# 307:	learn: 7.5058538	total: 2.87s	remaining: 3.18s
# 308:	learn: 7.5051433	total: 2.88s	remaining: 3.17s
# 309:	learn: 7.5044307	total: 2.88s	remaining: 3.16s
# 310:	learn: 7.5038113	total: 2.89s	remaining: 3.15s
# 311:	learn: 7.5033124	total: 2.9s	remaining: 3.14s
# 312:	learn: 7.5028899	total: 2.91s	remaining: 3.13s
# 313:	learn: 7.5023981	total: 2.92s	remaining: 3.12s
# 314:	learn: 7.5019093	total: 2.93s	remaining: 3.11s
# 315:	learn: 7.5015255	total: 2.94s	remaining: 3.1s
# 316:	learn: 7.5008930	total: 2.95s	remaining: 3.09s
# 317:	learn: 7.5003495	total: 2.95s	remaining: 3.08s
# 318:	learn: 7.4999236	total: 2.96s	remaining: 3.08s
# 319:	learn: 7.4992715	total: 2.97s	remaining: 3.06s
# 320:	learn: 7.4988195	total: 2.98s	remaining: 3.06s
# 321:	learn: 7.4982929	total: 2.99s	remaining: 3.05s
# 322:	learn: 7.4977038	total: 3s	remaining: 3.04s
# 323:	learn: 7.4972474	total: 3.01s	remaining: 3.03s
# 324:	learn: 7.4969129	total: 3.02s	remaining: 3.02s
# 325:	learn: 7.4964030	total: 3.03s	remaining: 3.01s
# 326:	learn: 7.4957181	total: 3.04s	remaining: 3s
# 327:	learn: 7.4953663	total: 3.04s	remaining: 2.99s
# 328:	learn: 7.4947197	total: 3.06s	remaining: 2.98s
# 329:	learn: 7.4941706	total: 3.06s	remaining: 2.97s
# 330:	learn: 7.4936237	total: 3.07s	remaining: 2.96s
# 331:	learn: 7.4929931	total: 3.08s	remaining: 2.95s
# 332:	learn: 7.4923747	total: 3.09s	remaining: 2.94s
# 333:	learn: 7.4918455	total: 3.1s	remaining: 2.93s
# 334:	learn: 7.4913511	total: 3.11s	remaining: 2.92s
# 335:	learn: 7.4908959	total: 3.12s	remaining: 2.91s
# 336:	learn: 7.4904513	total: 3.13s	remaining: 2.9s
# 337:	learn: 7.4899803	total: 3.14s	remaining: 2.9s
# 338:	learn: 7.4891980	total: 3.15s	remaining: 2.88s
# 339:	learn: 7.4888288	total: 3.15s	remaining: 2.88s
# 340:	learn: 7.4883012	total: 3.16s	remaining: 2.87s
# 341:	learn: 7.4879064	total: 3.17s	remaining: 2.86s
# 342:	learn: 7.4873704	total: 3.18s	remaining: 2.85s
# 343:	learn: 7.4870294	total: 3.19s	remaining: 2.84s
# 344:	learn: 7.4864677	total: 3.2s	remaining: 2.83s
# 345:	learn: 7.4858306	total: 3.21s	remaining: 2.82s
# 346:	learn: 7.4853914	total: 3.22s	remaining: 2.81s
# 347:	learn: 7.4850038	total: 3.23s	remaining: 2.8s
# 348:	learn: 7.4844289	total: 3.24s	remaining: 2.79s
# 349:	learn: 7.4839389	total: 3.25s	remaining: 2.78s
# 350:	learn: 7.4835440	total: 3.25s	remaining: 2.77s
# 351:	learn: 7.4831604	total: 3.26s	remaining: 2.76s
# 352:	learn: 7.4826708	total: 3.27s	remaining: 2.75s
# 353:	learn: 7.4822276	total: 3.28s	remaining: 2.75s
# 354:	learn: 7.4817682	total: 3.29s	remaining: 2.74s
# 355:	learn: 7.4813235	total: 3.3s	remaining: 2.73s
# 356:	learn: 7.4808095	total: 3.31s	remaining: 2.72s
# 357:	learn: 7.4805237	total: 3.32s	remaining: 2.71s
# 358:	learn: 7.4802918	total: 3.33s	remaining: 2.7s
# 359:	learn: 7.4797848	total: 3.34s	remaining: 2.69s
# 360:	learn: 7.4791413	total: 3.35s	remaining: 2.68s
# 361:	learn: 7.4787833	total: 3.35s	remaining: 2.67s
# 362:	learn: 7.4783571	total: 3.37s	remaining: 2.66s
# 363:	learn: 7.4779245	total: 3.37s	remaining: 2.65s
# 364:	learn: 7.4774007	total: 3.38s	remaining: 2.64s
# 365:	learn: 7.4772814	total: 3.39s	remaining: 2.63s
# 366:	learn: 7.4768273	total: 3.4s	remaining: 2.62s
# 367:	learn: 7.4763516	total: 3.41s	remaining: 2.61s
# 368:	learn: 7.4760642	total: 3.42s	remaining: 2.6s
# 369:	learn: 7.4755404	total: 3.43s	remaining: 2.59s
# 370:	learn: 7.4751258	total: 3.44s	remaining: 2.58s
# 371:	learn: 7.4748070	total: 3.45s	remaining: 2.58s
# 372:	learn: 7.4744273	total: 3.46s	remaining: 2.57s
# 373:	learn: 7.4738774	total: 3.47s	remaining: 2.56s
# 374:	learn: 7.4733361	total: 3.48s	remaining: 2.55s
# 375:	learn: 7.4728058	total: 3.48s	remaining: 2.54s
# 376:	learn: 7.4720673	total: 3.5s	remaining: 2.53s
# 377:	learn: 7.4716701	total: 3.5s	remaining: 2.52s
# 378:	learn: 7.4713431	total: 3.51s	remaining: 2.51s
# 379:	learn: 7.4709371	total: 3.52s	remaining: 2.5s
# 380:	learn: 7.4705702	total: 3.53s	remaining: 2.49s
# 381:	learn: 7.4701250	total: 3.54s	remaining: 2.48s
# 382:	learn: 7.4695825	total: 3.54s	remaining: 2.47s
# 383:	learn: 7.4691421	total: 3.56s	remaining: 2.46s
# 384:	learn: 7.4686791	total: 3.56s	remaining: 2.45s
# 385:	learn: 7.4681973	total: 3.57s	remaining: 2.44s
# 386:	learn: 7.4677327	total: 3.58s	remaining: 2.43s
# 387:	learn: 7.4674146	total: 3.59s	remaining: 2.42s
# 388:	learn: 7.4667355	total: 3.6s	remaining: 2.41s
# 389:	learn: 7.4663290	total: 3.61s	remaining: 2.4s
# 390:	learn: 7.4656257	total: 3.62s	remaining: 2.4s
# 391:	learn: 7.4651480	total: 3.63s	remaining: 2.39s
# 392:	learn: 7.4647714	total: 3.63s	remaining: 2.38s
# 393:	learn: 7.4643887	total: 3.64s	remaining: 2.37s
# 394:	learn: 7.4639234	total: 3.65s	remaining: 2.36s
# 395:	learn: 7.4636288	total: 3.66s	remaining: 2.35s
# 396:	learn: 7.4633181	total: 3.67s	remaining: 2.34s
# 397:	learn: 7.4630500	total: 3.68s	remaining: 2.33s
# 398:	learn: 7.4626850	total: 3.69s	remaining: 2.32s
# 399:	learn: 7.4623262	total: 3.69s	remaining: 2.31s
# 400:	learn: 7.4619864	total: 3.7s	remaining: 2.3s
# 401:	learn: 7.4615738	total: 3.71s	remaining: 2.29s
# 402:	learn: 7.4610436	total: 3.72s	remaining: 2.28s
# 403:	learn: 7.4606429	total: 3.73s	remaining: 2.27s
# 404:	learn: 7.4603496	total: 3.74s	remaining: 2.26s
# 405:	learn: 7.4600189	total: 3.75s	remaining: 2.25s
# 406:	learn: 7.4595205	total: 3.75s	remaining: 2.24s
# 407:	learn: 7.4589978	total: 3.76s	remaining: 2.23s
# 408:	learn: 7.4586583	total: 3.77s	remaining: 2.22s
# 409:	learn: 7.4583058	total: 3.78s	remaining: 2.21s
# 410:	learn: 7.4579607	total: 3.79s	remaining: 2.2s
# 411:	learn: 7.4575293	total: 3.8s	remaining: 2.19s
# 412:	learn: 7.4569749	total: 3.81s	remaining: 2.18s
# 413:	learn: 7.4564933	total: 3.81s	remaining: 2.17s
# 414:	learn: 7.4560953	total: 3.82s	remaining: 2.16s
# 415:	learn: 7.4555204	total: 3.83s	remaining: 2.15s
# 416:	learn: 7.4551298	total: 3.84s	remaining: 2.15s
# 417:	learn: 7.4548967	total: 3.85s	remaining: 2.13s
# 418:	learn: 7.4545247	total: 3.85s	remaining: 2.13s
# 419:	learn: 7.4541612	total: 3.87s	remaining: 2.12s
# 420:	learn: 7.4539008	total: 3.87s	remaining: 2.11s
# 421:	learn: 7.4534244	total: 3.88s	remaining: 2.1s
# 422:	learn: 7.4530572	total: 3.89s	remaining: 2.09s
# 423:	learn: 7.4523811	total: 3.9s	remaining: 2.08s
# 424:	learn: 7.4520162	total: 3.91s	remaining: 2.07s
# 425:	learn: 7.4515566	total: 3.92s	remaining: 2.06s
# 426:	learn: 7.4511887	total: 3.93s	remaining: 2.05s
# 427:	learn: 7.4508189	total: 3.94s	remaining: 2.04s
# 428:	learn: 7.4503286	total: 3.94s	remaining: 2.03s
# 429:	learn: 7.4498880	total: 3.95s	remaining: 2.02s
# 430:	learn: 7.4493985	total: 3.96s	remaining: 2.01s
# 431:	learn: 7.4488766	total: 3.97s	remaining: 2s
# 432:	learn: 7.4484345	total: 3.98s	remaining: 1.99s
# 433:	learn: 7.4481311	total: 3.99s	remaining: 1.98s
# 434:	learn: 7.4478207	total: 4s	remaining: 1.97s
# 435:	learn: 7.4475021	total: 4s	remaining: 1.97s
# 436:	learn: 7.4472350	total: 4.01s	remaining: 1.96s
# 437:	learn: 7.4467711	total: 4.02s	remaining: 1.95s
# 438:	learn: 7.4461561	total: 4.03s	remaining: 1.94s
# 439:	learn: 7.4458479	total: 4.04s	remaining: 1.93s
# 440:	learn: 7.4454172	total: 4.05s	remaining: 1.92s
# 441:	learn: 7.4449962	total: 4.05s	remaining: 1.91s
# 442:	learn: 7.4444592	total: 4.06s	remaining: 1.9s
# 443:	learn: 7.4440742	total: 4.07s	remaining: 1.89s
# 444:	learn: 7.4435942	total: 4.08s	remaining: 1.88s
# 445:	learn: 7.4433767	total: 4.09s	remaining: 1.87s
# 446:	learn: 7.4430664	total: 4.1s	remaining: 1.86s
# 447:	learn: 7.4428461	total: 4.11s	remaining: 1.85s
# 448:	learn: 7.4423380	total: 4.11s	remaining: 1.84s
# 449:	learn: 7.4418970	total: 4.12s	remaining: 1.83s
# 450:	learn: 7.4412716	total: 4.13s	remaining: 1.82s
# 451:	learn: 7.4408905	total: 4.14s	remaining: 1.81s
# 452:	learn: 7.4406974	total: 4.15s	remaining: 1.8s
# 453:	learn: 7.4404948	total: 4.16s	remaining: 1.79s
# 454:	learn: 7.4401329	total: 4.17s	remaining: 1.78s
# 455:	learn: 7.4395896	total: 4.17s	remaining: 1.77s
# 456:	learn: 7.4390747	total: 4.18s	remaining: 1.77s
# 457:	learn: 7.4386972	total: 4.19s	remaining: 1.76s
# 458:	learn: 7.4382580	total: 4.2s	remaining: 1.75s
# 459:	learn: 7.4377075	total: 4.21s	remaining: 1.74s
# 460:	learn: 7.4373161	total: 4.22s	remaining: 1.73s
# 461:	learn: 7.4366441	total: 4.23s	remaining: 1.72s
# 462:	learn: 7.4364327	total: 4.24s	remaining: 1.71s
# 463:	learn: 7.4360562	total: 4.25s	remaining: 1.7s
# 464:	learn: 7.4355289	total: 4.26s	remaining: 1.69s
# 465:	learn: 7.4350321	total: 4.27s	remaining: 1.69s
# 466:	learn: 7.4346448	total: 4.28s	remaining: 1.68s
# 467:	learn: 7.4341923	total: 4.29s	remaining: 1.67s
# 468:	learn: 7.4337782	total: 4.3s	remaining: 1.66s
# 469:	learn: 7.4333132	total: 4.31s	remaining: 1.65s
# 470:	learn: 7.4329416	total: 4.32s	remaining: 1.64s
# 471:	learn: 7.4325134	total: 4.32s	remaining: 1.63s
# 472:	learn: 7.4321120	total: 4.33s	remaining: 1.62s
# 473:	learn: 7.4316505	total: 4.34s	remaining: 1.61s
# 474:	learn: 7.4313372	total: 4.35s	remaining: 1.6s
# 475:	learn: 7.4309669	total: 4.36s	remaining: 1.59s
# 476:	learn: 7.4306246	total: 4.37s	remaining: 1.58s
# 477:	learn: 7.4302392	total: 4.38s	remaining: 1.57s
# 478:	learn: 7.4297219	total: 4.38s	remaining: 1.56s
# 479:	learn: 7.4292919	total: 4.39s	remaining: 1.56s
# 480:	learn: 7.4289553	total: 4.4s	remaining: 1.55s
# 481:	learn: 7.4287116	total: 4.41s	remaining: 1.54s
# 482:	learn: 7.4284453	total: 4.42s	remaining: 1.53s
# 483:	learn: 7.4280286	total: 4.43s	remaining: 1.52s
# 484:	learn: 7.4276557	total: 4.44s	remaining: 1.51s
# 485:	learn: 7.4273312	total: 4.45s	remaining: 1.5s
# 486:	learn: 7.4269683	total: 4.46s	remaining: 1.49s
# 487:	learn: 7.4266137	total: 4.47s	remaining: 1.48s
# 488:	learn: 7.4262522	total: 4.48s	remaining: 1.47s
# 489:	learn: 7.4256479	total: 4.49s	remaining: 1.47s
# 490:	learn: 7.4254330	total: 4.5s	remaining: 1.46s
# 491:	learn: 7.4250177	total: 4.5s	remaining: 1.45s
# 492:	learn: 7.4245637	total: 4.51s	remaining: 1.44s
# 493:	learn: 7.4241835	total: 4.52s	remaining: 1.43s
# 494:	learn: 7.4236965	total: 4.53s	remaining: 1.42s
# 495:	learn: 7.4233275	total: 4.54s	remaining: 1.41s
# 496:	learn: 7.4230508	total: 4.55s	remaining: 1.4s
# 497:	learn: 7.4225339	total: 4.56s	remaining: 1.39s
# 498:	learn: 7.4223906	total: 4.57s	remaining: 1.38s
# 499:	learn: 7.4220023	total: 4.58s	remaining: 1.37s
# 500:	learn: 7.4217176	total: 4.59s	remaining: 1.36s
# 501:	learn: 7.4213900	total: 4.6s	remaining: 1.35s
# 502:	learn: 7.4210214	total: 4.61s	remaining: 1.34s
# 503:	learn: 7.4206399	total: 4.61s	remaining: 1.34s
# 504:	learn: 7.4202521	total: 4.62s	remaining: 1.33s
# 505:	learn: 7.4196123	total: 4.63s	remaining: 1.32s
# 506:	learn: 7.4192492	total: 4.64s	remaining: 1.31s
# 507:	learn: 7.4187447	total: 4.65s	remaining: 1.3s
# 508:	learn: 7.4183707	total: 4.66s	remaining: 1.29s
# 509:	learn: 7.4178186	total: 4.67s	remaining: 1.28s
# 510:	learn: 7.4174128	total: 4.68s	remaining: 1.27s
# 511:	learn: 7.4171053	total: 4.69s	remaining: 1.26s
# 512:	learn: 7.4166387	total: 4.7s	remaining: 1.25s
# 513:	learn: 7.4163304	total: 4.71s	remaining: 1.25s
# 514:	learn: 7.4159100	total: 4.72s	remaining: 1.24s
# 515:	learn: 7.4155943	total: 4.72s	remaining: 1.23s
# 516:	learn: 7.4150691	total: 4.73s	remaining: 1.22s
# 517:	learn: 7.4146878	total: 4.74s	remaining: 1.21s
# 518:	learn: 7.4142345	total: 4.75s	remaining: 1.2s
# 519:	learn: 7.4138160	total: 4.76s	remaining: 1.19s
# 520:	learn: 7.4133597	total: 4.77s	remaining: 1.18s
# 521:	learn: 7.4129748	total: 4.78s	remaining: 1.17s
# 522:	learn: 7.4124768	total: 4.79s	remaining: 1.16s
# 523:	learn: 7.4121331	total: 4.8s	remaining: 1.15s
# 524:	learn: 7.4115932	total: 4.81s	remaining: 1.14s
# 525:	learn: 7.4112182	total: 4.82s	remaining: 1.14s
# 526:	learn: 7.4107547	total: 4.83s	remaining: 1.13s
# 527:	learn: 7.4103227	total: 4.83s	remaining: 1.12s
# 528:	learn: 7.4097066	total: 4.84s	remaining: 1.11s
# 529:	learn: 7.4092594	total: 4.85s	remaining: 1.1s
# 530:	learn: 7.4088271	total: 4.86s	remaining: 1.09s
# 531:	learn: 7.4081033	total: 4.87s	remaining: 1.08s
# 532:	learn: 7.4077973	total: 4.88s	remaining: 1.07s
# 533:	learn: 7.4072531	total: 4.89s	remaining: 1.06s
# 534:	learn: 7.4068273	total: 4.9s	remaining: 1.05s
# 535:	learn: 7.4065004	total: 4.91s	remaining: 1.04s
# 536:	learn: 7.4062393	total: 4.92s	remaining: 1.03s
# 537:	learn: 7.4057290	total: 4.93s	remaining: 1.03s
# 538:	learn: 7.4054874	total: 4.94s	remaining: 1.02s
# 539:	learn: 7.4052197	total: 4.95s	remaining: 1.01s
# 540:	learn: 7.4048786	total: 4.96s	remaining: 999ms
# 541:	learn: 7.4043711	total: 4.96s	remaining: 989ms
# 542:	learn: 7.4038599	total: 4.97s	remaining: 980ms
# 543:	learn: 7.4035147	total: 4.98s	remaining: 971ms
# 544:	learn: 7.4033009	total: 4.99s	remaining: 962ms
# 545:	learn: 7.4028205	total: 5s	remaining: 953ms
# 546:	learn: 7.4023471	total: 5.01s	remaining: 943ms
# 547:	learn: 7.4019863	total: 5.02s	remaining: 934ms
# 548:	learn: 7.4015068	total: 5.03s	remaining: 925ms
# 549:	learn: 7.4009718	total: 5.04s	remaining: 916ms
# 550:	learn: 7.4007107	total: 5.05s	remaining: 907ms
# 551:	learn: 7.4003483	total: 5.05s	remaining: 898ms
# 552:	learn: 7.3997965	total: 5.07s	remaining: 889ms
# 553:	learn: 7.3994352	total: 5.07s	remaining: 879ms
# 554:	learn: 7.3990814	total: 5.08s	remaining: 870ms
# 555:	learn: 7.3987501	total: 5.09s	remaining: 861ms
# 556:	learn: 7.3984108	total: 5.1s	remaining: 852ms
# 557:	learn: 7.3978949	total: 5.11s	remaining: 842ms
# 558:	learn: 7.3974836	total: 5.12s	remaining: 833ms
# 559:	learn: 7.3971277	total: 5.13s	remaining: 824ms
# 560:	learn: 7.3967583	total: 5.14s	remaining: 815ms
# 561:	learn: 7.3964420	total: 5.14s	remaining: 806ms
# 562:	learn: 7.3958859	total: 5.15s	remaining: 796ms
# 563:	learn: 7.3954451	total: 5.16s	remaining: 787ms
# 564:	learn: 7.3951216	total: 5.17s	remaining: 778ms
# 565:	learn: 7.3947775	total: 5.18s	remaining: 769ms
# 566:	learn: 7.3944538	total: 5.19s	remaining: 759ms
# 567:	learn: 7.3939792	total: 5.2s	remaining: 750ms
# 568:	learn: 7.3935549	total: 5.2s	remaining: 741ms
# 569:	learn: 7.3932466	total: 5.21s	remaining: 732ms
# 570:	learn: 7.3926525	total: 5.22s	remaining: 723ms
# 571:	learn: 7.3922147	total: 5.23s	remaining: 713ms
# 572:	learn: 7.3917683	total: 5.24s	remaining: 704ms
# 573:	learn: 7.3914839	total: 5.25s	remaining: 695ms
# 574:	learn: 7.3910668	total: 5.25s	remaining: 686ms
# 575:	learn: 7.3907119	total: 5.26s	remaining: 676ms
# 576:	learn: 7.3901346	total: 5.27s	remaining: 667ms
# 577:	learn: 7.3898207	total: 5.28s	remaining: 658ms
# 578:	learn: 7.3895569	total: 5.29s	remaining: 648ms
# 579:	learn: 7.3890911	total: 5.3s	remaining: 639ms
# 580:	learn: 7.3888365	total: 5.3s	remaining: 630ms
# 581:	learn: 7.3884651	total: 5.31s	remaining: 621ms
# 582:	learn: 7.3881185	total: 5.32s	remaining: 612ms
# 583:	learn: 7.3875943	total: 5.33s	remaining: 602ms
# 584:	learn: 7.3870801	total: 5.34s	remaining: 593ms
# 585:	learn: 7.3867301	total: 5.35s	remaining: 584ms
# 586:	learn: 7.3863034	total: 5.36s	remaining: 575ms
# 587:	learn: 7.3860532	total: 5.37s	remaining: 566ms
# 588:	learn: 7.3856472	total: 5.38s	remaining: 557ms
# 589:	learn: 7.3853448	total: 5.38s	remaining: 548ms
# 590:	learn: 7.3850057	total: 5.39s	remaining: 538ms
# 591:	learn: 7.3845185	total: 5.4s	remaining: 529ms
# 592:	learn: 7.3841386	total: 5.41s	remaining: 520ms
# 593:	learn: 7.3836224	total: 5.42s	remaining: 511ms
# 594:	learn: 7.3831471	total: 5.43s	remaining: 502ms
# 595:	learn: 7.3828647	total: 5.44s	remaining: 493ms
# 596:	learn: 7.3823807	total: 5.45s	remaining: 484ms
# 597:	learn: 7.3819546	total: 5.46s	remaining: 474ms
# 598:	learn: 7.3815807	total: 5.46s	remaining: 465ms
# 599:	learn: 7.3811424	total: 5.47s	remaining: 456ms
# 600:	learn: 7.3806306	total: 5.48s	remaining: 447ms
# 601:	learn: 7.3803009	total: 5.49s	remaining: 438ms
# 602:	learn: 7.3798513	total: 5.5s	remaining: 429ms
# 603:	learn: 7.3793228	total: 5.51s	remaining: 420ms
# 604:	learn: 7.3789993	total: 5.52s	remaining: 411ms
# 605:	learn: 7.3786038	total: 5.53s	remaining: 401ms
# 606:	learn: 7.3782495	total: 5.54s	remaining: 392ms
# 607:	learn: 7.3777238	total: 5.54s	remaining: 383ms
# 608:	learn: 7.3771934	total: 5.55s	remaining: 374ms
# 609:	learn: 7.3768364	total: 5.56s	remaining: 365ms
# 610:	learn: 7.3764782	total: 5.57s	remaining: 356ms
# 611:	learn: 7.3761448	total: 5.58s	remaining: 346ms
# 612:	learn: 7.3758196	total: 5.59s	remaining: 337ms
# 613:	learn: 7.3754305	total: 5.59s	remaining: 328ms
# 614:	learn: 7.3750060	total: 5.6s	remaining: 319ms
# 615:	learn: 7.3745726	total: 5.61s	remaining: 310ms
# 616:	learn: 7.3741944	total: 5.62s	remaining: 301ms
# 617:	learn: 7.3737157	total: 5.63s	remaining: 292ms
# 618:	learn: 7.3734417	total: 5.64s	remaining: 282ms
# 619:	learn: 7.3731018	total: 5.65s	remaining: 273ms
# 620:	learn: 7.3727697	total: 5.65s	remaining: 264ms
# 621:	learn: 7.3724531	total: 5.66s	remaining: 255ms
# 622:	learn: 7.3721451	total: 5.67s	remaining: 246ms
# 623:	learn: 7.3716431	total: 5.68s	remaining: 237ms
# 624:	learn: 7.3713266	total: 5.69s	remaining: 228ms
# 625:	learn: 7.3709726	total: 5.7s	remaining: 218ms
# 626:	learn: 7.3706657	total: 5.71s	remaining: 209ms
# 627:	learn: 7.3701784	total: 5.71s	remaining: 200ms
# 628:	learn: 7.3699559	total: 5.72s	remaining: 191ms
# 629:	learn: 7.3696037	total: 5.73s	remaining: 182ms
# 630:	learn: 7.3692573	total: 5.74s	remaining: 173ms
# 631:	learn: 7.3688050	total: 5.75s	remaining: 164ms
# 632:	learn: 7.3684300	total: 5.76s	remaining: 155ms
# 633:	learn: 7.3680393	total: 5.76s	remaining: 145ms
# 634:	learn: 7.3677224	total: 5.77s	remaining: 136ms
# 635:	learn: 7.3672330	total: 5.78s	remaining: 127ms
# 636:	learn: 7.3666872	total: 5.79s	remaining: 118ms
# 637:	learn: 7.3663496	total: 5.8s	remaining: 109ms
# 638:	learn: 7.3660864	total: 5.81s	remaining: 100ms
# 639:	learn: 7.3656930	total: 5.82s	remaining: 90.9ms
# 640:	learn: 7.3652733	total: 5.82s	remaining: 81.8ms
# 641:	learn: 7.3650295	total: 5.83s	remaining: 72.7ms
# 642:	learn: 7.3646876	total: 5.84s	remaining: 63.6ms
# 643:	learn: 7.3644228	total: 5.85s	remaining: 54.5ms
# 644:	learn: 7.3640865	total: 5.86s	remaining: 45.4ms
# 645:	learn: 7.3638260	total: 5.87s	remaining: 36.3ms
# 646:	learn: 7.3635153	total: 5.87s	remaining: 27.2ms
# 647:	learn: 7.3632444	total: 5.88s	remaining: 18.2ms
# 648:	learn: 7.3629364	total: 5.89s	remaining: 9.08ms
# 649:	learn: 7.3626095	total: 5.9s	remaining: 0us
#   CV RMSE  : 7.5649  |  Test RMSE: 7.4683  |  Gap: -0.0967
#   Test R²  : 0.4436
#   ✓ Saved → models\3.3-all_results_cache.joblib

# %% [markdown]
# ### EBM — Explainable Boosting Machine (glass-box model with native interpretability)
#
# EBM is a **Generalised Additive Model with pairwise interactions (GA²M)** from Microsoft Research's
# `interpret` library. Unlike SHAP (which post-hoc approximates a black-box), EBM is the model itself;
# its feature contributions are exact by construction.
#
# Why EBM for NHS PROMs:
# - Clinicians can inspect the **shape function** for each feature (e.g. "how does pre-op EQ-5D score
#   curve against predicted health gain?") — directly from `ebm.explain_global()`.
# - `interactions` parameter adds the top-k pairwise terms (e.g. Age × Pre-Op OKS) without losing interpretability.
# - Comparable accuracy to HistGBM on tabular benchmarks; meaningful confidence intervals on predictions.
#
# Tuned parameters: `max_rounds`, `learning_rate`, `max_bins`, `interactions`, `min_samples_leaf`.

# %%
if _ebm_available:
    for ds in all_data:
        tune_and_run(ds, 'EBM', n_trials=40)
else:
    print('EBM not available — run pip install interpret and restart the kernel.')
# Out:
# ▶  Tuning 2.1-Manual  ×  EBM  (40 Optuna trials)
#   Dropped 3728 train rows with null target.
#   Dropped 1820 test rows with null target.
#   Features: 48 numeric, 0 categorical
#   Year CV   : GroupKFold(2 year groups)  |  recency weight: Year 1=0.7, rest=1.0
#   Trial  40/40  RMSE=7.6092  trial_time=59.4s  ETA=0 s minnn
#   Optuna best CV RMSE     : 7.6090  (via GroupKFold(2 year groups))
#   Best params             : {'max_rounds': 2500, 'learning_rate': 0.03828165381968547, 'max_bins': 512, 'interactions': 15, 'min_samples_leaf': 20}
#   CV RMSE  : 7.5821  |  Test RMSE: 7.4723  |  Gap: -0.1098
#   Test R²  : 0.4430
#   ✓ Saved → models\3.3-all_results_cache.joblib

# %% [markdown]
# ### MLP — Multi-Layer Perceptron Neural Network
#
# A `MLPRegressor` (sklearn) with **Adam optimiser** and **early stopping**.
#
# Why MLP brings structural diversity to the ensemble:
# - Learns **non-linear feature combinations** via hidden layers — fundamentally different from the
#   additive/multiplicative inductive bias of tree ensembles.
# - With `StandardScaler` already in the pipeline, inputs arrive unit-normalised — a prerequisite for
#   stable gradient-based training.
# - `early_stopping=True` uses an internal 10% validation split to stop when val-RMSE plateaus,
#   avoiding epoch-level overfitting without manual iteration tuning.
#
# Tuned parameters: `hidden_layer_sizes` (architecture), `activation` (`relu`/`tanh`), `alpha` (L2 weight
# decay), `learning_rate_init` (initial Adam step size).
# Fixed: `solver=adam`, `max_iter=500`, `n_iter_no_change=20`.

# %%
for ds in all_data:
    tune_and_run(ds, 'MLP', n_trials=40)
# Out:
# ▶  Tuning 2.1-Manual  ×  MLP  (40 Optuna trials)
#   Dropped 3728 train rows with null target.
#   Dropped 1820 test rows with null target.
#   Features: 48 numeric, 0 categorical
#   Year CV   : GroupKFold(2 year groups)  |  recency weight: Year 1=0.7, rest=1.0
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial   1/40  RMSE=12.4348  trial_time=31.3s  ETA=20.3 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial   2/40  RMSE=12.9004  trial_time=10.2s  ETA=13.1 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial   3/40  RMSE=20.3281  trial_time=14.4s  ETA=11.5 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial   4/40  RMSE=21.3274  trial_time=3.9s  ETA=9.0 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial   5/40  RMSE=17.3706  trial_time=11.1s  ETA=8.3 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial   6/40  RMSE=12.3053  trial_time=3.7s  ETA=7.0 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial   7/40  RMSE=9.5784  trial_time=4.4s  ETA=6.2 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial   8/40  RMSE=19.7676  trial_time=4.4s  ETA=5.6 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial   9/40  RMSE=21.9104  trial_time=20.2s  ETA=5.9 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  10/40  RMSE=22.1307  trial_time=37.1s  ETA=7.0 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  11/40  RMSE=12.7029  trial_time=8.1s  ETA=6.5 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  12/40  RMSE=9.7367  trial_time=9.6s  ETA=6.2 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  13/40  RMSE=9.7413  trial_time=11.6s  ETA=5.9 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  14/40  RMSE=9.0875  trial_time=8.5s  ETA=5.5 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  15/40  RMSE=9.1478  trial_time=8.3s  ETA=5.2 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  16/40  RMSE=9.1501  trial_time=8.5s  ETA=4.9 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  17/40  RMSE=9.3808  trial_time=7.5s  ETA=4.6 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  18/40  RMSE=9.4796  trial_time=8.0s  ETA=4.3 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  19/40  RMSE=11.5657  trial_time=6.1s  ETA=4.0 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  20/40  RMSE=9.7097  trial_time=9.1s  ETA=3.8 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  21/40  RMSE=9.7463  trial_time=14.7s  ETA=3.6 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  22/40  RMSE=9.4293  trial_time=8.7s  ETA=3.4 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# ...
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  33/40  RMSE=9.5268  trial_time=7.7s  ETA=1.2 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  34/40  RMSE=9.2004  trial_time=7.5s  ETA=1.0 min
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  35/40  RMSE=11.6241  trial_time=4.1s  ETA=50 s
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  36/40  RMSE=23.2600  trial_time=16.3s  ETA=41 s
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  37/40  RMSE=12.4106  trial_time=3.5s  ETA=30 s
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  38/40  RMSE=19.5000  trial_time=7.9s  ETA=20 s
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  39/40  RMSE=10.2926  trial_time=4.0s  ETA=10 s
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256,) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (64, 32) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (256, 128) which is of type tuple.
#   optuna_warn(message)
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\optuna\distributions.py:502: UserWarning: Choices for a categorical distribution should be a tuple of None, bool, int, float and str for persistent storage but contains (128, 64, 32) which is of type tuple.
#   optuna_warn(message)
#   Trial  40/40  RMSE=8.8108  trial_time=9.1s  ETA=0 s
#   Optuna best CV RMSE     : 8.8108  (via GroupKFold(2 year groups))
#   Best params             : {'hidden_layer_sizes': (128, 64), 'activation': 'relu', 'alpha': 0.031109513468974833, 'learning_rate_init': 0.005838599513210474}
# c:\Users\mittall\source\EAISI\NHS\EAISI-NHS\.venv\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   CV RMSE  : 9.1282  |  Test RMSE: 10.6184  |  Gap: +1.4902 ⚠ possible overfit
#   Test R²  : -0.1248
#   ✓ Saved → models\3.3-all_results_cache.joblib

# %% [markdown]
# ## 7. Full Comparison — 3.3 Tuned Results + vs 3.1 Baseline
#
# Compares all (dataset × model) results from this notebook (3.3) against the 3.1 baseline.
# A row highlighted in gold = overall winner across both notebooks.

# %%
from pathlib import Path
import joblib
import polars as pl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ── 3.3 comparison table ──────────────────────────────────────────────────────
comparison_rows_33 = []
for ds_label, models_dict in all_results_33.items():
    for mdl_name, res in models_dict.items():
        comparison_rows_33.append({
            'Source':    '3.3-Tuned',
            'Dataset':   ds_label,
            'Model':     mdl_name,
            'CV RMSE':   round(res['cv_rmse'], 4),
            'CV R²':     round(res['cv_r2'],   4),
            'Test MAE':  round(res['test_mae'],  4),
            'Test RMSE': round(res['test_rmse'], 4),
            'Test R²':   round(res['test_r2'],   4),
        })

comparison_df_33 = pl.DataFrame(comparison_rows_33).sort('Test RMSE')

print('=== 3.3 Tuned Results ===\n')
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.width', None):
    display(comparison_df_33.to_pandas().reset_index(drop=True))

winner_33   = comparison_df_33.row(0, named=True)
print(f'\n>>> 3.3 WINNER  Dataset: {winner_33["Dataset"]}  Model: {winner_33["Model"]}')
print(f'    Test RMSE: {winner_33["Test RMSE"]}  |  R²: {winner_33["Test R²"]}')

# Save for downstream use (3.2-style analysis)
best_res_33      = all_results_33[winner_33['Dataset']][winner_33['Model']]
best_pipeline_33 = best_res_33['pipeline']
X_train_33       = best_res_33['X_train']
X_test_33        = best_res_33['X_test']
y_train_33       = best_res_33['y_train']
y_test_33        = best_res_33['y_test']
y_pred_33        = best_res_33['y_pred']
feature_names_33 = best_res_33['feature_names']
# Out:
# === 3.3 Tuned Results ===
#       Source     Dataset         Model  CV RMSE   CV R²  Test MAE  Test RMSE  \
# 0  3.3-Tuned  2.1-Manual      CatBoost   7.5649  0.4349    5.6312     7.4683
# 1  3.3-Tuned  2.1-Manual           EBM   7.5821  0.4323    5.6252     7.4723
# 2  3.3-Tuned  2.1-Manual       XGBoost   7.5752  0.4333    5.6401     7.4812
# 3  3.3-Tuned  2.1-Manual       HistGBM   7.5880  0.4314    5.6475     7.4889
# 4  3.3-Tuned  2.1-Manual         Lasso   7.6619  0.4203    5.6140     7.5464
# 5  3.3-Tuned  2.1-Manual         Ridge   7.6619  0.4203    5.6124     7.5466
# 6  3.3-Tuned  2.1-Manual  RandomForest   7.6624  0.4202    5.7383     7.5568
# 7  3.3-Tuned  2.1-Manual           MLP   9.1282  0.1770    7.4972    10.6184
#
#    Test R²
# 0   0.4436
# 1   0.4430
# 2   0.4417
# 3   0.4405
# 4   0.4319
# 5   0.4319
# 6   0.4303
# 7  -0.1248
# >>> 3.3 WINNER  Dataset: 2.1-Manual  Model: CatBoost
#     Test RMSE: 7.4683  |  R²: 0.4436

# %%
# ── Load 3.1 baseline for comparison ─────────────────────────────────────────
_RESULTS_PATH_31 = Path('./models/all_results_cache.joblib')

if _RESULTS_PATH_31.exists():
    all_results_31 = joblib.load(_RESULTS_PATH_31)
    comparison_rows_31 = []
    for ds_label, models_dict in all_results_31.items():
        for mdl_name, res in models_dict.items():
            comparison_rows_31.append({
                'Source':    '3.1-Baseline',
                'Dataset':   ds_label,
                'Model':     mdl_name,
                'CV RMSE':   round(res['cv_rmse'],   4),
                'CV R²':     round(res['cv_r2'],     4),
                'Test MAE':  round(res['test_mae'],  4),
                'Test RMSE': round(res['test_rmse'], 4),
                'Test R²':   round(res['test_r2'],   4),
            })

    comparison_df_31 = pl.DataFrame(comparison_rows_31).sort('Test RMSE')
    combined_df      = pl.concat([comparison_df_31, comparison_df_33]).sort('Test RMSE')

    print('=== Combined: 3.1 Baseline vs 3.3 Tuned ===\n')
    with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.width', None):
        display(combined_df.to_pandas().reset_index(drop=True))

    overall_winner = combined_df.row(0, named=True)
    print(f'\n>>> OVERALL WINNER  Source: {overall_winner["Source"]}  '
          f'Dataset: {overall_winner["Dataset"]}  Model: {overall_winner["Model"]}')
    print(f'    Test RMSE: {overall_winner["Test RMSE"]}  |  R²: {overall_winner["Test R²"]}')

    # Improvement of best 3.3 vs best 3.1
    best_31_rmse = comparison_df_31.row(0, named=True)['Test RMSE']
    best_33_rmse = comparison_df_33.row(0, named=True)['Test RMSE']
    delta        = best_31_rmse - best_33_rmse
    print(f'\n>>> HPO improvement: {delta:+.4f} RMSE  ({100*delta/best_31_rmse:+.1f}%)  3.1 best={best_31_rmse:.4f} → 3.3 best={best_33_rmse:.4f}')
else:
    print(f'3.1 cache not found at {_RESULTS_PATH_31}. Showing 3.3 results only.')
    combined_df = comparison_df_33
# Out:
# 3.1 cache not found at models\all_results_cache.joblib. Showing 3.3 results only.

# %%
# ── Visual comparison ─────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 3, figsize=(22, 6))
fig.suptitle('Test-Set Performance — 3.1 Baseline vs 3.3 Tuned (all datasets × models)', fontsize=13)

all_rows = combined_df.to_dicts()
labels   = [f'{r["Dataset"]}\n{r["Model"]}\n({r["Source"][2:4]})' for r in all_rows]
colors   = ['tomato' if r['Source'] == '3.1-Baseline' else 'steelblue' for r in all_rows]
colors[0] = 'gold'   # mark overall winner

for ax, metric in zip(axes, ['Test MAE', 'Test RMSE', 'Test R²']):
    values = [r[metric] for r in all_rows]
    ax.bar(labels, values, color=colors)
    ax.set_title(metric)
    ax.tick_params(axis='x', rotation=55, labelsize=6)

# Legend
from matplotlib.patches import Patch
legend_elements = [
    Patch(facecolor='tomato',    label='3.1 Baseline (no HPO)'),
    Patch(facecolor='steelblue', label='3.3 Tuned (Optuna)'),
    Patch(facecolor='gold',      label='Overall winner'),
]
axes[0].legend(handles=legend_elements, fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. CV vs Test RMSE Gap — Overfitting Diagnostic
#
# A large positive gap (Test RMSE >> CV RMSE) signals overfitting.
# A negative gap (Test RMSE < CV RMSE) may indicate the test set is slightly easier than training.

# %%
import math

gap_rows = []
for ds_label, models_dict in all_results_33.items():
    for mdl_name, res in models_dict.items():
        cv_r   = res['cv_rmse']
        test_r = res['test_rmse']
        if math.isnan(cv_r):
            continue
        gap_rows.append({
            'Label':     f'{ds_label}\n{mdl_name}',
            'CV RMSE':   cv_r,
            'Test RMSE': test_r,
            'Gap':       test_r - cv_r,
        })

gap_df = sorted(gap_rows, key=lambda x: x['Gap'], reverse=True)

labels_g     = [r['Label']    for r in gap_df]
cv_vals      = [r['CV RMSE']  for r in gap_df]
test_vals    = [r['Test RMSE']for r in gap_df]
gaps         = [r['Gap']      for r in gap_df]
gap_colors   = ['tomato' if g > 0.3 else 'steelblue' for g in gaps]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, max(5, len(gap_df) * 0.45)))
fig.suptitle('CV vs Test RMSE — Overfitting Diagnostic (3.3 Tuned Models)', fontsize=12)

y_pos = range(len(gap_df))
ax1.barh(y_pos, cv_vals,   alpha=0.7, color='steelblue', label='CV RMSE')
ax1.barh(y_pos, test_vals, alpha=0.4, color='tomato',    label='Test RMSE')
ax1.set_yticks(y_pos)
ax1.set_yticklabels(labels_g, fontsize=8)
ax1.set_xlabel('RMSE')
ax1.set_title('CV RMSE vs Test RMSE')
ax1.legend()

ax2.barh(y_pos, gaps, color=gap_colors, alpha=0.8)
ax2.axvline(0, color='black', linewidth=0.8)
ax2.axvline(0.3, color='grey', linewidth=0.6, linestyle='--', label='Gap > 0.3 (caution)')
ax2.set_yticks(y_pos)
ax2.set_yticklabels(labels_g, fontsize=8)
ax2.set_xlabel('Test RMSE − CV RMSE')
ax2.set_title('Overfitting Gap (tomato = caution)')
ax2.legend(fontsize=8)

plt.tight_layout()
plt.show()

print('\nModels with gap > 0.3 (potential overfit):')
flagged = [r for r in gap_df if r['Gap'] > 0.3]
if flagged:
    for r in flagged:
        print(f"  {r['Label'].replace(chr(10), ' × '):<45s}  gap={r['Gap']:+.4f}")
else:
    print('  None — all models generalise well.')
# Out:
# Models with gap > 0.3 (potential overfit):
#   2.1-Manual × MLP                               gap=+1.4902
