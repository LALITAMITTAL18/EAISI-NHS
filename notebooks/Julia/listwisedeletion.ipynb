# %% [markdown]
# Dataset listwise deletion

# %%
import polars as pl

# %%
df = pl.read_parquet(f'../Experiment/Knee/data/interim/2.0-preprocessing.parquet')
df.shape
# Out:
# (139236, 49)

# %%
df_clean = df.drop_nulls()
df_clean.shape
# Out:
# (96158, 49)

# %%
# Create a new DataFrame with column names as vertical rows
column_table = pl.DataFrame({
    "column_names": df_clean.columns
})

print(column_table)
# Out:
# shape: (49, 1)
# ┌─────────────────────────────────┐
# │ column_names                    │
# │ ---                             │
# │ str                             │
# ╞═════════════════════════════════╡
# │ Provider Code                   │
# │ Procedure                       │
# │ Revision Flag                   │
# │ Year                            │
# │ Age Band                        │
# │ …                               │
# │ Knee Replacement Pre-Op Q Conf… │
# │ Knee Replacement Pre-Op Q Shop… │
# │ Knee Replacement Pre-Op Q Stai… │
# │ Knee Replacement Pre-Op Q Scor… │
# │ Knee Replacement Post-Op Q Sco… │
# └─────────────────────────────────┘
